# %%
import header
from src.suppliers.suppliers_list.aliexpress import AffiliateLinksShortener
# Out:
# Master password for KeePass database: ········
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import header
# ----> 2 from src.suppliers.aliexpress import AffiliateLinksShortener
#
# File ~\Documents\repos\hypotez\src\suppliers\aliexpress\__init__.py:12
#      10 from .aliapi import AliApi
#      11 from .alirequests import AliRequests
# ---> 12 from .link_shortener import AffiliateLinksShortener
#      14 #from .scenarios import DealsFromXLS
#
# File ~\Documents\repos\hypotez\src\suppliers\aliexpress\link_shortener.py:12
#      10 from src.settings import gs
#      11 from src.webdriver import Driver, Chrome, Firefox, Edge
# ---> 12 from .scenarios import short_affiliate_link
#      13 #from src.suppliers.suppliers_list.aliexpress.scenarios.link_shortener_scenario import short_affiliate_link
#      14 from src.utils import j_loads
#
# File ~\Documents\repos\hypotez\src\suppliers\aliexpress\scenarios\__init__.py:10
#       6 from .version import __version__, __name__, __doc__, __details__, __annotations__,  __author__
#       8 #from .deals import DealsFromXLS
# ---> 10 from .promote_deal import AliPromoDeal
#      11 from .link_shortener_scenario import short_affiliate_link
#
# File ~\Documents\repos\hypotez\src\suppliers\aliexpress\scenarios\promote_deal.py:10
#       8 from src.settings import gs
#       9 from src.utils.jjson import j_loads, j_loads_ns
# ---> 10 from src.suppliers.aliexpress.affiliated_products_generator import AliAffiliatedProducts
#      12 class AliPromoDeal:
#      13     """! Рекламное сообщение с товарами и описаниями внутри """
#
# File ~\Documents\repos\hypotez\src\suppliers\aliexpress\affiliated_products_generator.py:19
#      17 from src.utils import pprint
#      18 from src.logger import logger
# ---> 19 from .link_shortener import AffiliateLinksShortener
#      21 class AliAffiliatedProducts(AliexpressApi):
#      22     """! Class to collect full product data from URLs product_ids
#      23     locator_description For more details on how to create templates for ad campaigns, see the section `Managing Aliexpress Ad Campaigns`
#      24     @code
#    (...)
#      30     @endcode
#      31     """
#
# ImportError: cannot import name 'AffiliateLinksShortener' from partially initialized module 'src.suppliers.suppliers_list.aliexpress.link_shortener' (most likely due to a circular import) (C:\Users\user\Documents\repos\hypotez\src\suppliers\aliexpress\link_shortener.py)

# %%
a = AffiliateLinksShortener('firefox')

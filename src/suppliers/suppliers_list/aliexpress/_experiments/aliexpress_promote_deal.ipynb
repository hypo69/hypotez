# %%
import header
from src.suppliers.suppliers_list.aliexpress import AliPromoDeal
from src.utils.printer import pprint
# Out:
# Master password for KeePass database: ········

# %%
deal = AliPromoDeal('150624_baseus_deals')

# %%
products = deal.prepare_products_for_deal()
# Out:
# 2024-06-26 06:09:47,527 - INFO - Start Firefox
# 2024-06-26 06:10:35,934 - INFO - cookies was saved to C:\Users\user\Documents\repos\hypotez\cookies\portals.aliexpress.com\firefox\cookie
# 2024-06-26 06:10:38,326 - INFO - Image saved locally to:C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\images\3256806549168768.png
# 2024-06-26 06:10:41,513 - INFO - File C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\parsed_products\3256806549168768.json was created succefully!
# 2024-06-26 06:10:42,266 - INFO - Image saved locally to:C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\images\3256806664544538.png
# 2024-06-26 06:10:44,812 - INFO - File C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\parsed_products\3256806664544538.json was created succefully!
# 2024-06-26 06:10:45,576 - INFO - Image saved locally to:C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\images\3256806618229209.png
# 2024-06-26 06:10:48,262 - INFO - File C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\parsed_products\3256806618229209.json was created succefully!
# 2024-06-26 06:10:48,952 - INFO - Image saved locally to:C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\images\3256806512732190.png
# 2024-06-26 06:10:51,495 - INFO - File C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\parsed_products\3256806512732190.json was created succefully!
# 2024-06-26 06:10:52,260 - INFO - Image saved locally to:C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\images\3256804489531583.png
# 2024-06-26 06:10:54,774 - INFO - File C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\parsed_products\3256804489531583.json was created succefully!
# 2024-06-26 06:10:55,479 - INFO - Image saved locally to:C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\images\3256806540530714.png
# 2024-06-26 06:10:58,039 - INFO - File C:\Users\user\Documents\repos\hypotez\data\aliexpress\event_promotion\150624_baseus_deals\parsed_products\3256806540530714.json was created succefully!

# %%
pprint(product)

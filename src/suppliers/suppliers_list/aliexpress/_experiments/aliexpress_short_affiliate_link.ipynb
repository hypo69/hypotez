# %%
import header
from src.utils.printer import pprint
from src.suppliers.suppliers_list.aliexpress import AliApi
...
url = 'https://aliexpress.com'

# %%
a = AliApi()

# %%
from src.suppliers.suppliers_list.aliexpress.api.api import AliexpressApi
pprint(AliexpressApi)
# Out:
# <class 'src.suppliers.suppliers_list.aliexpress.api.api.AliexpressApi'>
# Class: type
# ['object']
# Bases: None
# Methods:
# get_affiliate_links()
# get_categories()
# get_child_categories()
# get_hotproducts()
# get_parent_categories()
# retrieve_product_details()
# Properties:

# %%
pprint(a)
# Out:
# <src.suppliers.suppliers_list.aliexpress.aliapi.AliApi object at 0x00000145EE8FA5A0>
# Class: AliApi
# ['AliexpressApi']
# Bases: None
# Methods:
# get_affiliate_links()
# get_categories()
# get_child_categories()
# get_hotproducts()
# get_parent_categories()
# retrieve_product_categories()
# retrieve_product_details()
# retrieve_product_details_as_dict()
# Properties:
# _app_signature = None
# _currency = usd
# _key = 500950
# _language = en
# _secret = XVARez7wHym5nWfqY4rl7ZSfyPL1X0D6
# _tracking_id = default
# categories = None
# manager_campaigns = None
# manager_categories = None

# %%
d = a.driver

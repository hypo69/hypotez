# %%
import header
from src.utils import pprint
from src.suppliers.aliexpress import DealsFromXLS
# Out:
# Master password for KeePass database: ········
# 2024-06-12 00:03:34,949 - INFO -
#         CHROME - webdiver just started.
#         The driver will be selected, settings and profile will be loaded.
#         On my computer, this will takes about half a minute. Waiting...
#          None
# 2024-06-12 00:03:35,369 - INFO - --port=9500 None

# %%
deals_parser = DealsFromXLS(language='EN', currency= 'USD')
# Out:
# 2024-06-12 00:11:38,503 - INFO - Start parsing file: C:\Users\user\Documents\repos\hypotez\suppliers_external_data\aliexpress\excel\Sb58ae6d41c71472f818822c2492300f8b.xls None
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': '7PCJTF1C57N5',
#  'Code Quantity': 2999.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 25.57',
#  'Estimated direct linking commission': 'ILS 2.05',
#  'Estimated indirect linking commission': 'ILS 1.79',
#  'Image Url': 'https://ae01.alicdn.com/kf/HTB1Ti_tT3TqK1RjSZPhq6xfOFXaz.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 25.57',
#  'Positive Feedback': '93.7%',
#  'Product Desc': '55CM Matte Black Double Towel Bars Bathroom Towel Hanger '
#                  'Space Aluminum Bathroom Accessories Towel Rack Towel Ring  '
#                  'Toilet Brush',
#  'ProductId': 33013275833,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oFLd9Ms',
#  'Sales180Day': 35,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/1095246932027/p/1/e/6/t/10301/286099741770.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 5.0,
#  'Discount': '52%',
#  'Discount Price': 'ILS 58.54',
#  'Estimated direct linking commission': 'ILS 2.93',
#  'Estimated indirect linking commission': 'ILS 5.27',
#  'Image Url': 'https://ae01.alicdn.com/kf/S604590e1e3724a16911f0e4ccc931b1cm.jpg',
#  'Indirect linking commission rate (%)': 9.0,
#  'Origin Price': 'ILS 121.98',
#  'Positive Feedback': '94.2%',
#  'Product Desc': 'KUULAA Mini Power Bank 4500mAh - Portable Charger for iPhone '
#                  '15/14/13/12 Pro Max & Samsung/Xiaomi - External Battery '
#                  'PowerBank',
#  'ProductId': 1005005222350665,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_opSCxKc',
#  'Sales180Day': 6191,
#  'Video Url': None}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'JCWXFUS0V2TM',
#  'Code Quantity': 48330.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 70.00',
#  'Estimated direct linking commission': 'ILS 5.60',
#  'Estimated indirect linking commission': 'ILS 4.90',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sb4a7bda286ac49c2b0b5f7d5e208ef7ca.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 70.00',
#  'Positive Feedback': '91.9%',
#  'Product Desc': 'KEMIMOTO CE Motorcycle Gloves Winter Waterproof Warm Moto '
#                  'Guantes Touch Screen Motorbike Riding Gloves Carbon Fiber '
#                  'Protective',
#  'ProductId': 4000257871059,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDCPs04',
#  'Sales180Day': 219,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/1715152918/p/1/e/6/t/10301/334376524680.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 57.50',
#  'Code Name': 'NMT1502',
#  'Code Quantity': 92693.0,
#  'Code Start Time': '2024-05-26 08:20:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 9.0,
#  'Discount': '25%',
#  'Discount Price': 'ILS 178.76',
#  'Estimated direct linking commission': 'ILS 16.09',
#  'Estimated indirect linking commission': 'ILS 12.51',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa20c804fb7c2462196ed671ed364284cN.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 238.37',
#  'Positive Feedback': '88.7%',
#  'Product Desc': 'NAMSTE 300m³ Aroma Diffuser Electric Aromati Oasis 160ML '
#                  'Essential Oil Capacity Air Freshener Bluetooth Control '
#                  'Incense Burner',
#  'ProductId': 1005005260153229,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_okP46bE',
#  'Sales180Day': 200,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2670768132/p/1/e/6/t/10301/1100150383546.mp4'}
# {'Code End Time': '2024-06-23 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'C1RATW9J28QH',
#  'Code Quantity': 5000.0,
#  'Code Start Time': '2024-06-10 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.5,
#  'Discount': '30%',
#  'Discount Price': 'ILS 130.72',
#  'Estimated direct linking commission': 'ILS 13.73',
#  'Estimated indirect linking commission': 'ILS 9.15',
#  'Image Url': 'https://ae01.alicdn.com/kf/S4da5dc0744854ced95ab8c6ef6a671858.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 186.77',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'KEMIMOTO X3 UTV Black/Red Aluminum Anodized Door Opener Sets '
#                  'for Can am Maverick X3, Maverick X3 MAX 2/4 Doors 2017-2024',
#  'ProductId': 1005004345161203,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_opxgqVO',
#  'Sales180Day': 71,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2668203605/p/1/e/6/t/10301/1100115071591.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 103.50',
#  'Estimated direct linking commission': 'ILS 8.28',
#  'Estimated indirect linking commission': 'ILS 7.24',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sb9710ca71bb44139ad2f957c0a37f7e6d.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 103.50',
#  'Positive Feedback': '93.8%',
#  'Product Desc': '60L 90L Nylon Luggage Gym Bags Outdoor Bag Large Traveling '
#                  'Tas For Women Men Travel Duffle Handbags Sack Luggage Bag '
#                  'Gym XA15WD',
#  'ProductId': 1005002702150400,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oCcgfbe',
#  'Sales180Day': 61,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2096011803/p/1/e/6/t/10301/311059788871.mp4'}
# {'Code End Time': '2024-07-01 23:59:59',
#  'Code Minimum Spend': 'ILS 61.34',
#  'Code Name': '68563A',
#  'Code Quantity': 7591.0,
#  'Code Start Time': '2024-05-26 03:00:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '39%',
#  'Discount Price': 'ILS 96.87',
#  'Estimated direct linking commission': 'ILS 7.75',
#  'Estimated indirect linking commission': 'ILS 6.78',
#  'Image Url': 'https://ae01.alicdn.com/kf/S21cf3bf9bcda462099f916c10501850aa.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 161.43',
#  'Positive Feedback': '98.9%',
#  'Product Desc': '5PCS KAK 3" Universal Mute Wheel Office Chair Caster '
#                  'Replacement 60KG Casters Rubber Soft Safe Roller Furniture '
#                  'Wheel Hardware',
#  'ProductId': 32909255941,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDTaFWy',
#  'Sales180Day': 73,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/770240736/p/1/e/6/t/10301/349659112608.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 57.50',
#  'Code Name': 'QNM2GI3WPTUA',
#  'Code Quantity': 430.0,
#  'Code Start Time': '2024-05-01 20:40:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.0,
#  'Discount': '7%',
#  'Discount Price': 'ILS 67.69',
#  'Estimated direct linking commission': 'ILS 6.77',
#  'Estimated indirect linking commission': 'ILS 6.09',
#  'Image Url': 'https://ae01.alicdn.com/kf/H595e11b27ab241ff8fde2816e076b837X.jpg',
#  'Indirect linking commission rate (%)': 9.0,
#  'Origin Price': 'ILS 73.14',
#  'Positive Feedback': '95.9%',
#  'Product Desc': "Children's polar fleece boys and girls one-piece romper with "
#                  'feet one-piece romper warm pajamas spring, autumn and winter '
#                  'feet',
#  'ProductId': 1005003303025116,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_omFKiCU',
#  'Sales180Day': 60,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/1578030119/p/1/e/6/t/10301/326584880617.mp4'}
# {'Code End Time': '2024-07-31 23:59:59',
#  'Code Minimum Spend': 'ILS 15.82',
#  'Code Name': 'IKAPEL3',
#  'Code Quantity': 499.0,
#  'Code Start Time': '2024-05-14 02:46:00',
#  'Code Value': 'ILS 11.39',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '15%',
#  'Discount Price': 'ILS 127.79',
#  'Estimated direct linking commission': 'ILS 10.22',
#  'Estimated indirect linking commission': 'ILS 8.95',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sd2f4a18f4e394a689f5f0fe75b7a7dfbU.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 150.97',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'IKAPE V3 Espresso Tamper, Premium Barista Coffee Tamper with '
#                  'Calibrated Spring Loaded, 100% Stainless Steel Base Tamper',
#  'ProductId': 1005005527930366,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oF0qEhe',
#  'Sales180Day': 116,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2672928088/p/1/e/6/t/10301/1100147314760.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 5.0,
#  'Discount': '52%',
#  'Discount Price': 'ILS 84.99',
#  'Estimated direct linking commission': 'ILS 4.25',
#  'Estimated indirect linking commission': 'ILS 7.65',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sae60f4c2c4384a66b83fef67cd4e2a3fK.jpg',
#  'Indirect linking commission rate (%)': 9.0,
#  'Origin Price': 'ILS 177.07',
#  'Positive Feedback': '94.7%',
#  'Product Desc': 'KUULAA Mini Power Bank 5000mAh PowerBank QC PD Fast Charging '
#                  'For iPhone 15 14 13 Batterie Externe Portable Charger For '
#                  'Samsung',
#  'ProductId': 1005004514921625,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oFOIpV2',
#  'Sales180Day': 3918,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/237873760/p/1/e/6/t/10301/1100083515835.mp4'}
# {'Code End Time': '2024-07-31 23:48:00',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'FB3GWOW6EPCP',
#  'Code Quantity': 137.0,
#  'Code Start Time': '2024-06-05 23:48:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 19.5,
#  'Discount': '3%',
#  'Discount Price': 'ILS 27.98',
#  'Estimated direct linking commission': 'ILS 5.46',
#  'Estimated indirect linking commission': 'ILS 2.52',
#  'Image Url': 'https://ae01.alicdn.com/kf/S705c12f5ea784c0faa7a3e9123e7c702i.jpg',
#  'Indirect linking commission rate (%)': 9.0,
#  'Origin Price': 'ILS 28.90',
#  'Positive Feedback': '98.7%',
#  'Product Desc': 'Fashion TPU Soft Car Key Case Full Cover Shell For Toyota '
#                  'Corolla Camry RAV4 CHR C-HR Hilux Prius Land Cruiser Prado '
#                  'Accessories',
#  'ProductId': 1005004989524960,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oBtyXkY',
#  'Sales180Day': 69,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2670075908/p/1/e/6/t/10301/1100103560355.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': '7TROD11E00D4',
#  'Code Quantity': 98914.0,
#  'Code Start Time': '2024-05-02 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 11.58',
#  'Estimated direct linking commission': 'ILS 0.93',
#  'Estimated indirect linking commission': 'ILS 0.81',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa381bfb60c0a49d48361b1ed3be6af18V.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 11.58',
#  'Positive Feedback': '97.4%',
#  'Product Desc': '1 PC Ratcheting Wrenches  Quick Access Wrench Organizer From '
#                  'Gear To Tip',
#  'ProductId': 1005003000537281,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ooDYVmG',
#  'Sales180Day': 274,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2620695535/p/1/e/6/t/10301/324549713335.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 95.57',
#  'Estimated direct linking commission': 'ILS 7.65',
#  'Estimated indirect linking commission': 'ILS 6.69',
#  'Image Url': 'https://ae01.alicdn.com/kf/S338f43fa6e3d49be8a33f7f663041c35W.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 95.57',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'Libraton 20PCS Magnetic Nut Driver Set Impact Drill Driver '
#                  'Bit Set 1/4" Metric SAE Nut Driver 5-13mm & 3/16\'\'-1/2\'\' '
#                  'Nut Drivers',
#  'ProductId': 1005005489112502,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oo28KAo',
#  'Sales180Day': 50,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2668129854/p/1/e/6/t/10301/1100144303472.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 57.50',
#  'Code Name': 'NMT1502',
#  'Code Quantity': 92693.0,
#  'Code Start Time': '2024-05-26 08:20:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 4.5,
#  'Discount': '23%',
#  'Discount Price': 'ILS 194.78',
#  'Estimated direct linking commission': 'ILS 8.77',
#  'Estimated indirect linking commission': 'ILS 13.63',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sbe93155187674b9a914cad09a6559ccbL.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 252.97',
#  'Positive Feedback': '80.0%',
#  'Product Desc': '1500m³ Smart Bluetooth Aroma Diffuser Essential Oil Capacity '
#                  '200ML Atomization Strong Air Freshener Home Hotel',
#  'ProductId': 1005005302178065,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDbl7Cu',
#  'Sales180Day': 10,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2670768132/p/1/e/6/t/10301/1100104713051.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 7.0,
#  'Discount': '4%',
#  'Discount Price': 'ILS 64.21',
#  'Estimated direct linking commission': 'ILS 4.49',
#  'Estimated indirect linking commission': 'ILS 4.49',
#  'Image Url': 'https://ae01.alicdn.com/kf/S8803e20937c340c9a9d63c4f16976947Z.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 67.27',
#  'Positive Feedback': '94.3%',
#  'Product Desc': 'BEPOCAM Parking Surveillance Cable For BEPOCAM 4K ZD03 ZD72 '
#                  'ZD80 ZD68 ZD60 ZD59 ZD46 Dashcam Hardwire Kit 24H Parking '
#                  'Monitor',
#  'ProductId': 1005006008918207,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_olgHpmy',
#  'Sales180Day': 75,
#  'Video Url': None}
# {'Code End Time': '2024-07-20 23:59:59',
#  'Code Minimum Spend': 'ILS 5.28',
#  'Code Name': 'VGTMLPWLHQZW',
#  'Code Quantity': 465.0,
#  'Code Start Time': '2024-04-23 17:55:00',
#  'Code Value': 'ILS 3.96',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '4%',
#  'Discount Price': 'ILS 58.37',
#  'Estimated direct linking commission': 'ILS 4.67',
#  'Estimated indirect linking commission': 'ILS 4.09',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sbca71b3bb58c48cab8ebbe59f2fe8e36D.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 61.35',
#  'Positive Feedback': '97.1%',
#  'Product Desc': 'Brass 2 Tone Heart Solid Rings Women Jewelry Punk Style '
#                  'Designer Club Cocktail Party Gown Amazing Gift Trendy Boho '
#                  'Korean Japan',
#  'ProductId': 1005004869198248,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oCIvOze',
#  'Sales180Day': 96,
#  'Video Url': None}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 19.40',
#  'Estimated direct linking commission': 'ILS 1.55',
#  'Estimated indirect linking commission': 'ILS 1.36',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sac36129241bd4e2bb681f2693179351cP.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 19.40',
#  'Positive Feedback': '98.8%',
#  'Product Desc': 'Cartoon Rainbow Crayon Wall Stickers Kids Room Bedroom '
#                  'Background Decoration Wallpaper Home Decor Self Adhesive '
#                  'Nursery Decals',
#  'ProductId': 1005004833462027,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oD8qh80',
#  'Sales180Day': 190,
#  'Video Url': None}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 13.5,
#  'Discount': '29%',
#  'Discount Price': 'ILS 536.73',
#  'Estimated direct linking commission': 'ILS 72.46',
#  'Estimated indirect linking commission': 'ILS 37.57',
#  'Image Url': 'https://ae01.alicdn.com/kf/S88f27a871d364e51a8ff9b538f9975e9X.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 766.74',
#  'Positive Feedback': '80.0%',
#  'Product Desc': 'KEMIMOTO #2881985 UTV Extended Wider Fender Flares '
#                  'Compatible with Polaris RZR XP 1000 / Turbo/S 1000/900 / '
#                  '900S 2014-2023',
#  'ProductId': 1005001651885409,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ooIaogk',
#  'Sales180Day': 21,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/226867735/p/1/e/6/t/10301/1100078928033.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'J70OOVEM9IXI',
#  'Code Quantity': 8873.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 11.54',
#  'Estimated direct linking commission': 'ILS 0.92',
#  'Estimated indirect linking commission': 'ILS 0.81',
#  'Image Url': 'https://ae01.alicdn.com/kf/S709875d40e7445ce99ed50094c5269026.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 11.54',
#  'Positive Feedback': '96.8%',
#  'Product Desc': 'AC100V-240V to DC5V/12V/24V Lighting Transformer 1A 2A 3A 5A '
#                  '6A 8A 10A Power Supply Adapter Converter Charger For LED '
#                  'Strip CCTV',
#  'ProductId': 1005003657344351,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ol7GqL6',
#  'Sales180Day': 148,
#  'Video Url': None}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 19.17',
#  'Code Name': '8KACVQ3PBSFP',
#  'Code Quantity': 4891.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.5,
#  'Discount': '2%',
#  'Discount Price': 'ILS 203.48',
#  'Estimated direct linking commission': 'ILS 21.37',
#  'Estimated indirect linking commission': 'ILS 14.24',
#  'Image Url': 'https://ae01.alicdn.com/kf/S70ac943630314d29b34e0b301fd332b9V.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 209.00',
#  'Positive Feedback': '90.0%',
#  'Product Desc': 'BAKALA New Design Shark Shape Sesign Modern Popular Bathroom '
#                  'Basin Faucet Brass Mixer Tap BR-SR',
#  'ProductId': 33031960055,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oENCEri',
#  'Sales180Day': 50,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/202233708/p/1/e/6/t/10301/1100074579391.mp4'}
# {'Code End Time': '2024-07-31 23:48:00',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'FB3GWOW6EPCP',
#  'Code Quantity': 137.0,
#  'Code Start Time': '2024-06-05 23:48:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 15.0,
#  'Discount': '3%',
#  'Discount Price': 'ILS 21.39',
#  'Estimated direct linking commission': 'ILS 3.21',
#  'Estimated indirect linking commission': 'ILS 1.93',
#  'Image Url': 'https://ae01.alicdn.com/kf/S29b9fb5f036e4bdab22a3f059a8e595aO.jpg',
#  'Indirect linking commission rate (%)': 9.0,
#  'Origin Price': 'ILS 22.08',
#  'Positive Feedback': '94.4%',
#  'Product Desc': 'Fashion TPU Car Key Case Cover Shell Protector For '
#                  'Volkswagen VW Polo Golf 7 GTI Tiguan Passat Beetle UP Skoda '
#                  'Octavia A7 Kodiaq',
#  'ProductId': 1005005629234595,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oksv4ni',
#  'Sales180Day': 203,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2670075908/p/1/e/6/t/10301/1100152896491.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '55%',
#  'Discount Price': 'ILS 102.16',
#  'Estimated direct linking commission': 'ILS 8.17',
#  'Estimated indirect linking commission': 'ILS 7.15',
#  'Image Url': 'https://ae01.alicdn.com/kf/S1bd4cf68278746a7a2f5d49e9b0c54aaH.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 227.06',
#  'Positive Feedback': '84.5%',
#  'Product Desc': 'V8 Wholesale Induction Control RC Helicopters Toy Gift FPV '
#                  'VR Mini Drone 4k HD Aerial Photography Folding Quadcopter '
#                  'With Camera',
#  'ProductId': 1005003385451498,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDkl4P2',
#  'Sales180Day': 171,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/52019941/p/1/e/6/t/10301/330987691251.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 57.50',
#  'Code Name': 'HP48AHB1CI9Y',
#  'Code Quantity': 433.0,
#  'Code Start Time': '2024-06-01 00:00:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 18.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 92.35',
#  'Estimated direct linking commission': 'ILS 16.62',
#  'Estimated indirect linking commission': 'ILS 6.46',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sc31301d4692f4ba4a0978b27ed65a051p.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 92.35',
#  'Positive Feedback': '94.5%',
#  'Product Desc': '1.5mm Neoprene Shorty Mens Wetsuit UV-proof Front Zip Lycra '
#                  'Long Sleeves Diving Suit for Underwater Snorkeling Swimming '
#                  'Surfing',
#  'ProductId': 1005004012433553,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_okLO5gC',
#  'Sales180Day': 248,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/228445616/p/1/e/6/t/10301/1100166417041.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'JCWXFUS0V2TM',
#  'Code Quantity': 48330.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 172.74',
#  'Estimated direct linking commission': 'ILS 13.82',
#  'Estimated indirect linking commission': 'ILS 12.09',
#  'Image Url': 'https://ae01.alicdn.com/kf/S2d7b77a1f1ed4b13b808e18e9a2d649ae.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 172.74',
#  'Positive Feedback': '94.3%',
#  'Product Desc': 'KEMIMOTO Electric Window Windshield Wiper Motor Kit '
#                  'Compatible with Polaris RZR XP 1000 Ranger for Can-am '
#                  'Maverick X3 for Cfmoto',
#  'ProductId': 1005005288605444,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_okIqBVw',
#  'Sales180Day': 78,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/205755010/p/1/e/6/t/10301/1100129769810.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 82.99',
#  'Estimated direct linking commission': 'ILS 6.64',
#  'Estimated indirect linking commission': 'ILS 5.81',
#  'Image Url': 'https://ae01.alicdn.com/kf/S522ba0b9b1ce400a936475b68e275a04m.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 82.99',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'TOLESA 6PCs Bar Clamps for Woodworking, Quick Grip Clamps 45 '
#                  'Lbs Load Limits 6Pc Light Duty One Handed Clamps & Spreader '
#                  '4 & 6"',
#  'ProductId': 1005005366872414,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_omh0oBw',
#  'Sales180Day': 49,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2671946250/p/1/e/6/t/10301/1100153423586.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 3.80',
#  'Code Name': '2BFFCFI0QL7L',
#  'Code Quantity': 79344.0,
#  'Code Start Time': '2024-05-31 19:10:00',
#  'Code Value': 'ILS 3.80',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 18.35',
#  'Estimated direct linking commission': 'ILS 1.47',
#  'Estimated indirect linking commission': 'ILS 1.28',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sd80fd42807af438ab1c1a8b78440a688p.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 18.35',
#  'Positive Feedback': '92.9%',
#  'Product Desc': 'RC Car Accessories 6028 6029 6030 6031 High Speed Toy Car '
#                  'Upgrade Part RC Parts，For SCY 16101 16102 16103 16201',
#  'ProductId': 1005005523834115,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oEKANnI',
#  'Sales180Day': 152,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2672042638/p/1/e/6/t/10301/1100212965048.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 4.75',
#  'Code Name': 'IFKLS6GQTRKM',
#  'Code Quantity': 248.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 4.75',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '49%',
#  'Discount Price': 'ILS 35.75',
#  'Estimated direct linking commission': 'ILS 2.86',
#  'Estimated indirect linking commission': 'ILS 2.50',
#  'Image Url': 'https://ae01.alicdn.com/kf/S164d55b775ab46caa6c70a8cc4bc15c7L.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 70.11',
#  'Positive Feedback': '93.5%',
#  'Product Desc': 'Shapewear Bodysuit Women Tummy Firm Control Waist Trainer '
#                  'Body Shaper Bodysuit Reducing and Shaping Shapers Bodysuit',
#  'ProductId': 1005006024623013,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_onHP6F2',
#  'Sales180Day': 241,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2677635073/p/1/e/6/t/10301/4000186004801.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 3.80',
#  'Code Name': '2BFFCFI0QL7L',
#  'Code Quantity': 79344.0,
#  'Code Start Time': '2024-05-31 19:10:00',
#  'Code Value': 'ILS 3.80',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 16.74',
#  'Estimated direct linking commission': 'ILS 1.76',
#  'Estimated indirect linking commission': 'ILS 1.17',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa6ab9b90fe9d415a900bfb1929f9579c8.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 16.74',
#  'Positive Feedback': '98.2%',
#  'Product Desc': '2023 RC Car Accessories  Pro High Speed SCY 16101 16102 '
#                  '16103 16201 16101pro 16102 CarPRO  Rc Cars for Adults   Rc '
#                  'Drift Car',
#  'ProductId': 1005005568580062,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ok73fGg',
#  'Sales180Day': 383,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2672042638/p/1/e/6/t/10301/1100150354050.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 76.67',
#  'Code Name': 'KX83NT2UCDV9',
#  'Code Quantity': 91.0,
#  'Code Start Time': '2024-04-30 00:00:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '3%',
#  'Discount Price': 'ILS 116.46',
#  'Estimated direct linking commission': 'ILS 9.32',
#  'Estimated indirect linking commission': 'ILS 8.15',
#  'Image Url': 'https://ae01.alicdn.com/kf/H4916dbc4603749d49af3c24229c8851bT.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 120.72',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'Women Underwire Sports Bra Plus Size Self-adjustment High '
#                  'Impact Max Control Non Padded Gym Yoga Underwear 2023 '
#                  'SportWear',
#  'ProductId': 4001028415741,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oExe0uk',
#  'Sales180Day': 33,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2206366295153/p/1/e/6/t/10301/292102688472.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 76.67',
#  'Code Name': 'GHA65QM7TWAD',
#  'Code Quantity': 474.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 76.63',
#  'Estimated direct linking commission': 'ILS 6.51',
#  'Estimated indirect linking commission': 'ILS 5.36',
#  'Image Url': 'https://ae01.alicdn.com/kf/H4bd7dcbb55b845f2ba4abdbf0e5f8d34W.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 76.63',
#  'Positive Feedback': '86.3%',
#  'Product Desc': 'MAMEN Phone DSLR Camera Vlog Tripod Vlogging Kit with Remote '
#                  'Control Microphone LED Light for Smartphone Interview Live '
#                  'YouTube',
#  'ProductId': 1005002842745789,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_opYu1z2',
#  'Sales180Day': 90,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/3836974816/p/1/e/6/t/10301/315511031716.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 9.0,
#  'Discount': '2%',
#  'Discount Price': 'ILS 32.20',
#  'Estimated direct linking commission': 'ILS 2.90',
#  'Estimated indirect linking commission': 'ILS 2.25',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa13e20175e7844bebb28764e352cf391N.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 32.96',
#  'Positive Feedback': '95.5%',
#  'Product Desc': '6 pairs Winter Woman socks Kawaii Cartoon Cute 3D Dog Cat '
#                  'Paw Pattern Female Fleece Warm Home Floor Sleeping snowfield '
#                  'Thick',
#  'ProductId': 1005003832869051,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_opJMZ3m',
#  'Sales180Day': 307,
#  'Video Url': None}
# {'Code End Time': '2024-06-23 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'PZXEQE17UFSL',
#  'Code Quantity': 5000.0,
#  'Code Start Time': '2024-06-10 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 13.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 32.70',
#  'Estimated direct linking commission': 'ILS 4.41',
#  'Estimated indirect linking commission': 'ILS 2.29',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sf8361c4830724780ab879dbea20ccf2cd.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 32.70',
#  'Positive Feedback': '92.5%',
#  'Product Desc': 'UTV Sports Roll Bar Cages Grab Handle Holder For Can-am '
#                  'Commander Maverick x3 1000 Compatible with Polaris RZR '
#                  'Ranger For Jeep',
#  'ProductId': 1005006031754816,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDaoxeM',
#  'Sales180Day': 91,
#  'Video Url': None}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'JCWXFUS0V2TM',
#  'Code Quantity': 48330.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 91.20',
#  'Estimated direct linking commission': 'ILS 7.30',
#  'Estimated indirect linking commission': 'ILS 6.38',
#  'Image Url': 'https://ae01.alicdn.com/kf/S1472834bd5bd4f1ba18c6a1829c5ee83d.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 91.20',
#  'Positive Feedback': '87.6%',
#  'Product Desc': 'KEMIMOTO Motorcycle Windshield Deflector Adjustable '
#                  'Universal for BMW R1250GS R1200GS Heighten Extension '
#                  'Windscreen Accessories',
#  'ProductId': 1005005351703103,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_olv9g5Q',
#  'Sales180Day': 557,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/205755010/p/1/e/6/t/10301/1100145195236.mp4'}
# {'Code End Time': '2024-06-23 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'C1RATW9J28QH',
#  'Code Quantity': 5000.0,
#  'Code Start Time': '2024-06-10 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 13.5,
#  'Discount': '39%',
#  'Discount Price': 'ILS 339.64',
#  'Estimated direct linking commission': 'ILS 45.85',
#  'Estimated indirect linking commission': 'ILS 23.77',
#  'Image Url': 'https://ae01.alicdn.com/kf/S47d839930e6d47aa84b0bc467cc6e4757.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 566.05',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'KEMIMOTO UTV Electronic Device Tablet Holder Storage Box for '
#                  'CFMOTO for CF-MOTO ZForce 1000 950 Sport, 950 H.O. SPORT, '
#                  '950 HO EX',
#  'ProductId': 1005005878488995,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oooKFic',
#  'Sales180Day': 40,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2668203605/p/1/e/6/t/10301/1100166159886.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 36.92',
#  'Code Name': 'PULYDGV99NQV',
#  'Code Quantity': 2779.0,
#  'Code Start Time': '2024-04-26 00:00:00',
#  'Code Value': 'ILS 3.69',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 44.47',
#  'Estimated direct linking commission': 'ILS 3.56',
#  'Estimated indirect linking commission': 'ILS 3.11',
#  'Image Url': 'https://ae01.alicdn.com/kf/S3c4a31fc6a574a4bb8816652a71d3439t.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 44.47',
#  'Positive Feedback': '94.9%',
#  'Product Desc': 'Watch Tool Repair Back Cover Presser Set 12pcs/18pcs Metal '
#                  'Watch Case Presser Press Fitting Dies Watchmaker Maintenance '
#                  'Tools',
#  'ProductId': 1005005892475242,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oCWKBMC',
#  'Sales180Day': 154,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2667576785/p/1/e/6/t/10301/1100188789144.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 15.37',
#  'Code Name': 'JYKR147',
#  'Code Quantity': 432.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 15.33',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 4.0,
#  'Discount': '43%',
#  'Discount Price': 'ILS 77.66',
#  'Estimated direct linking commission': 'ILS 3.11',
#  'Estimated indirect linking commission': 'ILS 6.99',
#  'Image Url': 'https://ae01.alicdn.com/kf/S74107e6196ce405f80dd4fb31ca2ab33e.jpg',
#  'Indirect linking commission rate (%)': 9.0,
#  'Origin Price': 'ILS 137.70',
#  'Positive Feedback': '96.1%',
#  'Product Desc': 'UGREEN 130W USB C Car Charger For Xiaomi iPhone 15 Samsung '
#                  'Galaxy S24 Laptops Tabet PD3.0 Fast Charging USB Type C Car '
#                  'Charger',
#  'ProductId': 1005004530469845,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_olgzZ1a',
#  'Sales180Day': 3775,
#  'Video Url': None}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 11.54',
#  'Code Name': 'IAKEN15BMGY8',
#  'Code Quantity': 6583.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 11.50',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '2%',
#  'Discount Price': 'ILS 67.32',
#  'Estimated direct linking commission': 'ILS 5.39',
#  'Estimated indirect linking commission': 'ILS 4.71',
#  'Image Url': 'https://ae01.alicdn.com/kf/S3e92726afafe4888959e21cfe4946fc41.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 68.93',
#  'Positive Feedback': '98.2%',
#  'Product Desc': 'Truelove Pet Training Leash and Collar Durable Slip Lead Dog '
#                  'Leash Heavy Duty Comfortable Strong Rope Leash No Pull Pet '
#                  'TLL2575',
#  'ProductId': 1005004653105284,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oovSIqg',
#  'Sales180Day': 38,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/221193997/p/1/e/6/t/10301/1100156868072.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'JCWXFUS0V2TM',
#  'Code Quantity': 48330.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 41.63',
#  'Estimated direct linking commission': 'ILS 3.33',
#  'Estimated indirect linking commission': 'ILS 2.91',
#  'Image Url': 'https://ae01.alicdn.com/kf/S8407b9fa5c544724aa223ae534092b60Y.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 41.63',
#  'Positive Feedback': '91.8%',
#  'Product Desc': 'Universal Motorcycle Handlebar Bag with Touchscreen Phone '
#                  'Storage Bag For BMW R1200GS R 1250GS For Suzuki For Kawasaki',
#  'ProductId': 1005005439511651,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oC41yy8',
#  'Sales180Day': 752,
#  'Video Url': None}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 7.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 61.34',
#  'Estimated direct linking commission': 'ILS 4.29',
#  'Estimated indirect linking commission': 'ILS 4.29',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sbcede3928a8c4f5486c10efbeb0d0c5dg.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 61.34',
#  'Positive Feedback': '91.0%',
#  'Product Desc': '925 Sterling Silver Rainbow Tennis Bracelet 2mm Round '
#                  'Diamond Chain for Men and Women Fine Jewelry Bright Wedding '
#                  'Party Gifts',
#  'ProductId': 1005005376740642,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oBOLyj6',
#  'Sales180Day': 65,
#  'Video Url': None}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 41.98',
#  'Estimated direct linking commission': 'ILS 3.36',
#  'Estimated indirect linking commission': 'ILS 2.94',
#  'Image Url': 'https://ae01.alicdn.com/kf/S50a9f4255be24e48b0a1a2e9053966402.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 41.98',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'EZARC 5PC 2/4-Cutter Carbide Tips SDS-Plus Rotary Hammer '
#                  'Drill Bit Set for Reinforced Concrete, Masonry, Marble, '
#                  'Brick and Tile',
#  'ProductId': 1005002019563663,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ooz7ZpS',
#  'Sales180Day': 43,
#  'Video Url': None}
# {'Code End Time': '2024-07-28 23:59:59',
#  'Code Minimum Spend': 'ILS 3.17',
#  'Code Name': 'UV2DFCHMN9U2',
#  'Code Quantity': 988.0,
#  'Code Start Time': '2024-06-02 06:20:00',
#  'Code Value': 'ILS 3.16',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.0,
#  'Discount': '4%',
#  'Discount Price': 'ILS 15.01',
#  'Estimated direct linking commission': 'ILS 1.50',
#  'Estimated indirect linking commission': 'ILS 1.05',
#  'Image Url': 'https://ae01.alicdn.com/kf/H7a35eeee17094f49be83fe86811cf207x.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 15.76',
#  'Positive Feedback': '96.8%',
#  'Product Desc': '4 Pairs MTB Bicycle Hydraulic Disc Ceramics Brake Pads For '
#                  'SHIMANO  HAYES SRAM AVID Magura Cycling Bike Part '
#                  'Accessories',
#  'ProductId': 1005002938489585,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ol06ILE',
#  'Sales180Day': 120,
#  'Video Url': None}
# {'Code End Time': '2024-06-23 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'PZXEQE17UFSL',
#  'Code Quantity': 5000.0,
#  'Code Start Time': '2024-06-10 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.0,
#  'Discount': '40%',
#  'Discount Price': 'ILS 139.88',
#  'Estimated direct linking commission': 'ILS 13.99',
#  'Estimated indirect linking commission': 'ILS 9.79',
#  'Image Url': 'https://ae01.alicdn.com/kf/S34dd0420d38b4f8f970133845e587fcaP.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 233.15',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'KEMIMOTO X3 UTV RH Passenger Side Lateral Panel Gas Cap '
#                  'Cover 705010334 for Can Am Maverick X3 Max R RR 900 '
#                  '2017-2022',
#  'ProductId': 1005004328386089,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDxYYWu',
#  'Sales180Day': 26,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2668203605/p/1/e/6/t/10301/4000174524628.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 4.75',
#  'Code Name': 'IFKLS6GQTRKM',
#  'Code Quantity': 248.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 4.75',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '45%',
#  'Discount Price': 'ILS 48.07',
#  'Estimated direct linking commission': 'ILS 3.85',
#  'Estimated indirect linking commission': 'ILS 3.36',
#  'Image Url': 'https://ae01.alicdn.com/kf/S07613a11dd7646f4935ff02f603c7dd1L.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 87.41',
#  'Positive Feedback': '91.2%',
#  'Product Desc': 'Women Full Body Shapewear Bodysuit for Belly Control '
#                  'Seamless Firm Waist Trainer Body Shaper Bodysuit',
#  'ProductId': 1005005778101044,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_okagKUM',
#  'Sales180Day': 285,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2677635073/p/1/e/6/t/10301/4000057888922.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '4%',
#  'Discount Price': 'ILS 27.57',
#  'Estimated direct linking commission': 'ILS 2.21',
#  'Estimated indirect linking commission': 'ILS 1.93',
#  'Image Url': 'https://ae01.alicdn.com/kf/S532d52981bbf4f29a2b6e7c37f1096bba.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 28.97',
#  'Positive Feedback': '95.4%',
#  'Product Desc': 'Large Capacity Canvas Solid Letter Tote Bag Versatile '
#                  "Handbag for Commuter Work Student Class Underarm Women's Bag "
#                  'shopping bag',
#  'ProductId': 1005005848861169,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ok8wb4Y',
#  'Sales180Day': 87,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2674443683/p/1/e/6/t/10301/1100167965081.mp4'}
# {'Code End Time': None,
#  'Code Minimum Spend': None,
#  'Code Name': None,
#  'Code Quantity': None,
#  'Code Start Time': None,
#  'Code Value': None,
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 9.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 75.29',
#  'Estimated direct linking commission': 'ILS 7.15',
#  'Estimated indirect linking commission': 'ILS 5.27',
#  'Image Url': 'https://ae01.alicdn.com/kf/S20b31dd26f8f4ecba7ba856b01e8b3b4w.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 75.29',
#  'Positive Feedback': '90.6%',
#  'Product Desc': 'EZARC Hot Melt Glue Gun 100W Heavy Duty Full Size Glue Gun '
#                  'Kit with 20pcs Glue Sticks, for DIY, Arts & Crafts Projects, '
#                  'Sealing',
#  'ProductId': 1005002022308834,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_o2cNAR6',
#  'Sales180Day': 100,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2210045374964/p/1/e/6/t/10301/331460768956.mp4'}
# {'Code End Time': '2024-07-29 23:59:59',
#  'Code Minimum Spend': 'ILS 15.82',
#  'Code Name': '7PAMH4UFXMO1',
#  'Code Quantity': 219.0,
#  'Code Start Time': '2024-05-01 00:00:00',
#  'Code Value': 'ILS 3.16',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 13.76',
#  'Estimated direct linking commission': 'ILS 1.10',
#  'Estimated indirect linking commission': 'ILS 0.96',
#  'Image Url': 'https://ae01.alicdn.com/kf/S47bbeb80e66c444f8ddbd8c718dbca2bH.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 13.76',
#  'Positive Feedback': '87.8%',
#  'Product Desc': 'For Samsung Galaxy Tab S8 S7 Plus Ultra S7+ S7 FE S7fe 12.4 '
#                  'Tab A8 Ceramic Matte Film Screen Protector No fingerprint '
#                  'Not Glass',
#  'ProductId': 1005004364289219,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oFb4S3E',
#  'Sales180Day': 643,
#  'Video Url': None}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 7.71',
#  'Code Name': 'CULA25',
#  'Code Quantity': 4961.0,
#  'Code Start Time': '2024-04-21 23:45:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 24.27',
#  'Estimated direct linking commission': 'ILS 1.94',
#  'Estimated indirect linking commission': 'ILS 1.70',
#  'Image Url': 'https://ae01.alicdn.com/kf/S614a3e33390d4e3fab81654a02c094ee8.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 24.27',
#  'Positive Feedback': '98.9%',
#  'Product Desc': 'RHINO RESCUE Tactical Chest Seal Vented,Military-Grade '
#                  'Trauma Care for Combat Medics Chest Sealing Patch,IFAK '
#                  'Supplies',
#  'ProductId': 1005002018216616,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ontKr8u',
#  'Sales180Day': 325,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/244185965/p/1/e/6/t/10301/1100121704244.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 19.17',
#  'Code Name': 'I6UNBUDI2C7E',
#  'Code Quantity': 788.0,
#  'Code Start Time': '2024-06-01 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 16.37',
#  'Estimated direct linking commission': 'ILS 1.39',
#  'Estimated indirect linking commission': 'ILS 1.15',
#  'Image Url': 'https://ae01.alicdn.com/kf/S311fe735efbd4aa898a41689926ede9cy.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 16.37',
#  'Positive Feedback': '94.2%',
#  'Product Desc': 'JCD Soldering Iron 908 Series 60W/80W Multi-function Button '
#                  'Adjustable Temperature 110V/220V LCD Digital Display Welding '
#                  'Tools',
#  'ProductId': 1005006039725441,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ooPeptE',
#  'Sales180Day': 615,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/226829558/p/1/e/6/t/10301/1100181855359.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 3.80',
#  'Code Name': '2BFFCFI0QL7L',
#  'Code Quantity': 79344.0,
#  'Code Start Time': '2024-05-31 19:10:00',
#  'Code Value': 'ILS 3.80',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 13.45',
#  'Estimated direct linking commission': 'ILS 1.08',
#  'Estimated indirect linking commission': 'ILS 0.94',
#  'Image Url': 'https://ae01.alicdn.com/kf/S877ba646ed6347eeae4b8232f029d3e7o.jpg',
# ...
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'RWS2570LPBA6',
#  'Code Quantity': 486.0,
#  'Code Start Time': '2024-05-31 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 7.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 36.19',
#  'Estimated direct linking commission': 'ILS 2.53',
#  'Estimated indirect linking commission': 'ILS 2.53',
#  'Image Url': 'https://ae01.alicdn.com/kf/S337508b1e2f74f07b05e0703e8096198n.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 36.19',
#  'Positive Feedback': '98.6%',
#  'Product Desc': 'Electric Water Gallon Bottle Pump Foldable Automatic Water '
#                  'Dispenser 19 Liters Bottle Rechargeable Desktop Drinking '
#                  'Water Pump',
#  'ProductId': 1005006678722881,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_omqQ9bQ',
#  'Sales180Day': 52,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/232035836/p/1/e/6/t/10301/1100118336988.mp4'}
# {'Code End Time': '2024-07-28 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'IE0OQLYGJDE3',
#  'Code Quantity': 49094.0,
#  'Code Start Time': '2024-04-30 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 20.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 9.43',
#  'Estimated direct linking commission': 'ILS 1.93',
#  'Estimated indirect linking commission': 'ILS 0.66',
#  'Image Url': 'https://ae01.alicdn.com/kf/S622755cca682432bb1bcd10a0518cc64h.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 9.43',
#  'Positive Feedback': '98.5%',
#  'Product Desc': 'For Xiaomi 1S Roborock Q7 MAX / MAX+ S5 MAX S6 S50 S55 Mop '
#                  'parts Vacuum Cleaner Cleaning Mop Cloth Accessories',
#  'ProductId': 1005004212519234,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oovq7wU',
#  'Sales180Day': 78,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/250739053/p/1/e/6/t/10301/1100017784025.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 11.61',
#  'Code Name': '8PMNMVKMK4RF',
#  'Code Quantity': 99740.0,
#  'Code Start Time': '2024-05-30 00:00:00',
#  'Code Value': 'ILS 11.60',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 20.0,
#  'Discount': '9%',
#  'Discount Price': 'ILS 62.89',
#  'Estimated direct linking commission': 'ILS 12.58',
#  'Estimated indirect linking commission': 'ILS 4.40',
#  'Image Url': 'https://ae01.alicdn.com/kf/S7f45ec5937324dd199916188d48c7b1bv.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 69.69',
#  'Positive Feedback': '93.3%',
#  'Product Desc': 'NAMSTE100ml Perfume Fragrance Oil Essential Oil For Electric '
#                  'Diffuser Room Fragrance Home Flavoring Aroma Diffuser '
#                  'Essential Oil',
#  'ProductId': 1005006609360290,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oC9ZdaU',
#  'Sales180Day': 16,
#  'Video Url': None}
# {'Code End Time': '2024-07-28 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'IE0OQLYGJDE3',
#  'Code Quantity': 49094.0,
#  'Code Start Time': '2024-04-30 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 12.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 9.93',
#  'Estimated direct linking commission': 'ILS 1.24',
#  'Estimated indirect linking commission': 'ILS 0.70',
#  'Image Url': 'https://ae01.alicdn.com/kf/Se7e00c95d81e4bc78e26f97a13ac9d7cG.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 9.93',
#  'Positive Feedback': '90.0%',
#  'Product Desc': 'Washable Dust HEPA Filter Replacement Accessories For Dyson '
#                  'DC45 DC30 DC31 DC34 DC35 DC44 Robot Vacuum Cleaner Filters '
#                  'Parts',
#  'ProductId': 1005004010278511,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oEQ74Xi',
#  'Sales180Day': 44,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2210917281045/p/1/e/6/t/10301/350668085910.mp4'}
# {'Code End Time': '2024-07-28 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'IE0OQLYGJDE3',
#  'Code Quantity': 49094.0,
#  'Code Start Time': '2024-04-30 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 9.51',
#  'Estimated direct linking commission': 'ILS 1.00',
#  'Estimated indirect linking commission': 'ILS 0.67',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa9e68d2490f24cc7b6fedae095e92d54f.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 9.51',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'For Xiaomi MIJIA 1C STYTJ01ZHM Robot Vacuum Cleaner Cleaning '
#                  'Cloth Mop Water Tank Accessories Robot Vacuum Cleaner Parts',
#  'ProductId': 1005002267893957,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_okerm4c',
#  'Sales180Day': 58,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2210917281045/p/1/e/6/t/10301/301080115565.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'XWRYCAH9MNJK',
#  'Code Quantity': 1965.0,
#  'Code Start Time': '2024-06-02 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 47.08',
#  'Estimated direct linking commission': 'ILS 3.77',
#  'Estimated indirect linking commission': 'ILS 3.30',
#  'Image Url': 'https://ae01.alicdn.com/kf/Ha909411b5ba0446799fde034e4d901492.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 47.08',
#  'Positive Feedback': '89.5%',
#  'Product Desc': 'RQ12 replacement shaver heads for Philips RQ1250 RQ1260 '
#                  'RQ1275 RQ1280 RQ1290 RQ1250CC RQ1260CC RQ1280CC RQ 1050 1060 '
#                  '1090 Razor',
#  'ProductId': 32757123358,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oB8BSok',
#  'Sales180Day': 168,
#  'Video Url': None}
# {'Code End Time': '2024-07-31 23:59:59',
#  'Code Minimum Spend': 'ILS 38.34',
#  'Code Name': 'N0EZ1T2GY1J3',
#  'Code Quantity': 99979.0,
#  'Code Start Time': '2024-06-01 04:10:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '0%',
#  'Discount Price': 'ILS 37.91',
#  'Estimated direct linking commission': 'ILS 3.03',
#  'Estimated indirect linking commission': 'ILS 2.65',
#  'Image Url': 'https://ae01.alicdn.com/kf/S755914f9dfa74b3a8caeb33fb6271157x.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 37.91',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'For Dyson V15 Hepa Filter Robot Vacuum Cleaner Accessories '
#                  'V15 washable Detect Vacuum Filters replaceable parts',
#  'ProductId': 1005005639066868,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oBulg3E',
#  'Sales180Day': 24,
#  'Video Url': None}
# {'Code End Time': '2024-07-01 23:59:59',
#  'Code Minimum Spend': 'ILS 3.17',
#  'Code Name': 'FRFR7K9BXGGD',
#  'Code Quantity': 500.0,
#  'Code Start Time': '2024-06-02 00:00:00',
#  'Code Value': 'ILS 3.16',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 11.5,
#  'Discount': '48%',
#  'Discount Price': 'ILS 25.22',
#  'Estimated direct linking commission': 'ILS 2.90',
#  'Estimated indirect linking commission': 'ILS 1.77',
#  'Image Url': 'https://ae01.alicdn.com/kf/H9aaf4bb4a02e4a81a3c1af62c05bcd546.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 49.44',
#  'Positive Feedback': '91.7%',
#  'Product Desc': 'Vacuum Food Sealer Bags Roll Storage For Kitchen Packaging '
#                  'Sealing Machine Fresh Keeping 12 15 20 25 28 30 35*500cm BPA '
#                  'Free',
#  'ProductId': 32819592156,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oBVj48k',
#  'Sales180Day': 125,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2370934378/p/1/e/6/t/10301/224928416921.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 11.61',
#  'Code Name': '8PMNMVKMK4RF',
#  'Code Quantity': 99740.0,
#  'Code Start Time': '2024-05-30 00:00:00',
#  'Code Value': 'ILS 11.60',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 20.0,
#  'Discount': '54%',
#  'Discount Price': 'ILS 56.59',
#  'Estimated direct linking commission': 'ILS 11.32',
#  'Estimated indirect linking commission': 'ILS 3.96',
#  'Image Url': 'https://ae01.alicdn.com/kf/S7f45ec5937324dd199916188d48c7b1bv.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 125.43',
#  'Positive Feedback': '94.8%',
#  'Product Desc': 'NAMSTE100ml Perfume Fragrance Oil Essential Oil For Electric '
#                  'Diffuser Room Fragrance Home Flavoring Aroma Diffuser '
#                  'Essential Oil',
#  'ProductId': 1005006641536188,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oClug7S',
#  'Sales180Day': 75,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2603087109/p/1/e/6/t/10301/1100218702593.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 11.61',
#  'Code Name': '8PMNMVKMK4RF',
#  'Code Quantity': 99740.0,
#  'Code Start Time': '2024-05-30 00:00:00',
#  'Code Value': 'ILS 11.60',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 20.0,
#  'Discount': '54%',
#  'Discount Price': 'ILS 71.57',
#  'Estimated direct linking commission': 'ILS 14.31',
#  'Estimated indirect linking commission': 'ILS 5.01',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa6b3ba61a9784504a9c207486a874156b.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 158.62',
#  'Positive Feedback': '92.7%',
#  'Product Desc': 'NAMSTE Aroma Essential Oil Hotel Series 100ML Use In Aroma '
#                  'Diffuser Fragrance Essential Oil Is Suitable For Home Office '
#                  'SPA Club',
#  'ProductId': 1005006153721266,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oEyBNd6',
#  'Sales180Day': 40,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2603087109/p/1/e/6/t/10301/1100154048623.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 76.67',
#  'Code Name': 'AV1497',
#  'Code Quantity': 99903.0,
#  'Code Start Time': '2024-05-30 00:00:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '50%',
#  'Discount Price': 'ILS 77.82',
#  'Estimated direct linking commission': 'ILS 6.23',
#  'Estimated indirect linking commission': 'ILS 5.45',
#  'Image Url': 'https://ae01.alicdn.com/kf/S7e9d8f9ba1924232ba6fc0512fe15186r.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 155.68',
#  'Positive Feedback': '92.9%',
#  'Product Desc': 'Namste Hotel Aroma Diffuser Essential Oil 100ML Pure Plant '
#                  'Aromatic Oils Fragrance Scent Electric Smell For Home Air '
#                  'Freshener',
#  'ProductId': 1005005072711844,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDatftK',
#  'Sales180Day': 231,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/247387327/p/1/e/6/t/10301/1100157245513.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 11.61',
#  'Code Name': '8PMNMVKMK4RF',
#  'Code Quantity': 99740.0,
#  'Code Start Time': '2024-05-30 00:00:00',
#  'Code Value': 'ILS 11.60',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 20.0,
#  'Discount': '54%',
#  'Discount Price': 'ILS 48.80',
#  'Estimated direct linking commission': 'ILS 9.76',
#  'Estimated indirect linking commission': 'ILS 3.42',
#  'Image Url': 'https://ae01.alicdn.com/kf/S3ca1b0951fed4c2eb3a3e26273b173c3M.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 108.17',
#  'Positive Feedback': '92.8%',
#  'Product Desc': 'NAMSTE Aroma Fragrance Oils 100ml Flower And Fruit Series '
#                  'Scent Machine Essential Oil Diffuser For House Hotel Office '
#                  'Spa',
#  'ProductId': 1005006546022745,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oChhLwM',
#  'Sales180Day': 92,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2603087109/p/1/e/6/t/10301/1100218700931.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 191.68',
#  'Code Name': 'C6L4QM5P2D8A',
#  'Code Quantity': 9858.0,
#  'Code Start Time': '2024-06-01 00:00:00',
#  'Code Value': 'ILS 19.17',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 8.0,
#  'Discount': '10%',
#  'Discount Price': 'ILS 159.44',
#  'Estimated direct linking commission': 'ILS 12.76',
#  'Estimated indirect linking commission': 'ILS 11.16',
#  'Image Url': 'https://ae01.alicdn.com/kf/S17696fa2378a4c1ea501d5d2501496d6T.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 177.84',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'NAMSTE Aroma Oil Diffuser Machine Automatic Air Freshener '
#                  '200ML Capacity WIFI Control Electric Fragrance Device For '
#                  'Home Hotel',
#  'ProductId': 1005006412484034,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oDJN5W8',
#  'Sales180Day': 60,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/239640434/p/1/e/6/t/10301/1100208243658.mp4'}
# {'Code End Time': '2024-07-28 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'IE0OQLYGJDE3',
#  'Code Quantity': 49094.0,
#  'Code Start Time': '2024-04-30 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 12.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 9.78',
#  'Estimated direct linking commission': 'ILS 1.22',
#  'Estimated indirect linking commission': 'ILS 0.68',
#  'Image Url': 'https://ae01.alicdn.com/kf/S0d661753eb2a4eceb9912d588a618991U.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 9.78',
#  'Positive Feedback': '92.0%',
#  'Product Desc': 'High Quality mop cloths for Roborock T7 T7S T7plus T7Splus '
#                  'S7 Mopping Cloth Spare Parts',
#  'ProductId': 1005002567789822,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_ol2pTKk',
#  'Sales180Day': 33,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2210917281045/p/1/e/6/t/10301/308365759124.mp4'}
# {'Code End Time': '2024-06-30 23:59:59',
#  'Code Minimum Spend': 'ILS 76.67',
#  'Code Name': 'AV1497',
#  'Code Quantity': 99903.0,
#  'Code Start Time': '2024-05-30 00:00:00',
#  'Code Value': 'ILS 7.67',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.0,
#  'Discount': '52%',
#  'Discount Price': 'ILS 77.36',
#  'Estimated direct linking commission': 'ILS 7.74',
#  'Estimated indirect linking commission': 'ILS 5.42',
#  'Image Url': 'https://ae01.alicdn.com/kf/Se517ae96edd6499eafe001e7614d13108.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 164.57',
#  'Positive Feedback': '95.2%',
#  'Product Desc': 'Namste New Hotel Diffuser Essential Oils 100ML Fragrance Oil '
#                  'Electric Smell For Home Perfume Oil Room Fragrance Air '
#                  'Freshener',
#  'ProductId': 1005006594135801,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_on5gXIy',
#  'Sales180Day': 93,
#  'Video Url': None}
# {'Code End Time': '2024-07-28 23:59:59',
#  'Code Minimum Spend': 'ILS 3.87',
#  'Code Name': 'IE0OQLYGJDE3',
#  'Code Quantity': 49094.0,
#  'Code Start Time': '2024-04-30 00:00:00',
#  'Code Value': 'ILS 3.83',
#  'Currency': 'ILS',
#  'Direct linking commission rate (%)': 10.5,
#  'Discount': '0%',
#  'Discount Price': 'ILS 23.69',
#  'Estimated direct linking commission': 'ILS 2.49',
#  'Estimated indirect linking commission': 'ILS 1.66',
#  'Image Url': 'https://ae01.alicdn.com/kf/Sa4b562bc1cd449ce8d6d569bab1a7557P.jpg',
#  'Indirect linking commission rate (%)': 7.0,
#  'Origin Price': 'ILS 23.69',
#  'Positive Feedback': '100.0%',
#  'Product Desc': 'Roborock Dyad U10 WD1S1A Wireless Floor Scrubber Vacuum '
#                  'Cleaner Parts Detachable Roller Brush Washable HEPA Filter '
#                  'Accessories',
#  'ProductId': 1005003875892594,
#  'Promotion Url': 'https://s.click.aliexpress_com.com/e/_oC7PmsM',
#  'Sales180Day': 65,
#  'Video Url': 'https://video.aliexpress-media.com/play/u/ae_sg_item/2210917281045/p/1/e/6/t/10301/347474066939.mp4'}

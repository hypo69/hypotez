# %%
import notebook_header
from notebook_header import start_supplier, \
pprint, jprint, logger, j_dumps, j_loads, \
Driver, execute_locator, Supplier, Product, ProductFields, \
SN, SF, Path, gs
import re, shutil
from selenium.webdriver.remote.webelement import WebElement
# Out:
# Master password for keepass database: ········
# NoneType: None
# 2024-01-31 13:19:14,247 - ERROR - Error v2
# NoneType: None

# %%
s = start_supplier('hb', 'en')
""" s - на протяжении всего кода означает запущенный инстанс класса `Supplier` """
# Out:
# 2024-01-31 13:19:14,303 - INFO -
#         -----------------------------------------
#                 Старт hb
#         -----------------------------------------
# 2024-01-31 13:19:14,308 - INFO - hb Begin to attach driver ...
# 2024-01-31 13:19:14,313 - INFO -
#         -----------------------------------------------------
#         Старт вебдрайвера firefox.
#         Будет выбран драйвер, подключатся настройки и профиль.
#         На моем компьютере это занимает около полуминуты. Ждем...
#         -----------------------------------------------------
# 2024-01-31 13:19:14,315 - INFO -  Firefox ...
# 2024-01-31 13:19:33,293 - INFO -  ... стартовал
# 2024-01-31 13:19:33,307 - DEBUG -  ... драйвер подключился за 19 seconds
# NoneType: None
# ' s - на протяжении всего кода означает запущенный инстанс класса `Supplier` '

# %%
p: Product = Product(s)
l: dict = s.locators['product']
d: Driver = s.driver
f: ProductFields = ProductFields(s)
f.associations = ''

# %%
"""! @debug Тестовый сценарий. Нужен для правильного распределиня категорий """
s.current_scenario: dict =  {
      "url": "https://hbdeadsea.co.il/product-category/bodyspa/feet-hand-treatment/",
      "name": "טיפוח כפות ידיים ורגליים",
      "condition": "new",
      "presta_categories": {
        "default_category": 11259,
        "additional_categories": []
      }
    }

# %%
d.get_url(s.current_scenario['url'])
# Out:
# 2024-01-31 13:20:08,916 - DEBUG - Страница загрузилась за 35.56345725059509
# NoneType: None
# 2024-01-31 13:20:08,922 - INFO -  Новый URI https://hbdeadsea.co.il/product-category/bodyspa/feet-hand-treatment/
# True

# %%
list_products_in_category: list = s.related_modules.get_list_products_in_category(s)
"""! Получил список товаров в категории """
# Out:
# 2024-01-31 13:20:09,141 - INFO -  Найдено 16 товаров
# '! Получил список товаров в категории '

# %%
d.get_url(list_products_in_category[0])
"""! перешел по первому url из списка """
# Out:
# 2024-01-31 13:20:10,647 - DEBUG - Страница загрузилась за 1.4912855625152588
# NoneType: None
# 2024-01-31 13:20:10,658 - INFO -  Новый URI https://hbdeadsea.co.il/product/%d7%a7%d7%a8%d7%9d-%d7%98%d7%99%d7%a4%d7%95%d7%9c%d7%99-%d7%9e%d7%95%d7%9c%d7%98%d7%99-%d7%95%d7%99%d7%98%d7%9e%d7%99%d7%9f-%d7%9c%d7%99%d7%93%d7%99%d7%99%d7%9d-%d7%95%d7%9c%d7%a6%d7%99%d7%a4%d7%95-2/
# '! перешел по первому url из списка '

# %%
prod_fields_dict = s.related_modules.grab_product_page(s)
pass
# Out:
# 2024-01-31 13:20:11,688 - WARNING - не найден СПИСОК элементов
# 2024-01-31 13:20:11,693 - WARNING - не найден ОДИН элемент
# 2024-01-31 13:20:11,694 - WARNING - не найден СПИСОК элементов с ожиданием
# 2024-01-31 13:20:11,700 - WARNING - не найден ОДИН элемент с ожиданием
# {'@note': 'Получаю через локатор '
#           'product_reference_and_volume_and_price_for_100',
#  'action': None,
#  'attribute': 'innerText',
#  'by': 'XPATH',
#  'logic for action[AND|OR|XOR|VALUE|null]': None,
#  'mandatory': True,
#  'selector': '',
#  'use_mouse': False}
# 2024-01-31 13:20:11,720 - DEBUG - Не вернулся ОБЯЗАТЕЛЬНЫЙ элемент по локатору:
#                 None
# NoneType: None
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\tools\string_normalizer.py", line 75, in normalize_price
#     return float (price)
#            ^^^^^^^^^^^^^
# ValueError: could not convert string to float: ''
# 2024-01-31 13:20:11,724 - ERROR - Ошибка нормализации `price`
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\tools\string_normalizer.py", line 75, in normalize_price
#     return float (price)
#            ^^^^^^^^^^^^^
# ValueError: could not convert string to float: ''

# %%
prod = grab_product_page(s)

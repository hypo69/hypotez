# %%
import header 
import copy
#from src.webdriver.selenium.driver import Driver, Chrome
from src.endpoints.advertisement.facebook.promoter import FacebookPromoter
from src.logger.logger import logger

import asyncio
from pydoll.browser.chrome import Chrome
from pydoll.constants import Key
# Out:
# 🔑 Found password in password.txt (DEBUG MODE)
# ✅ Successfully opened KeePass database: D:\repos\hypotez\secrets\credentials.kdbx
# Failed to extract Aliexpress API key from KeePass 'types.SimpleNamespace' object has no attribute 'aliexpress_com'
# Failed to load Aliexpress credentials
# Failed to load GAPI credentials
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\onela\AppData\Local\Temp\ipykernel_7252\2604485252.py", line 8, in <module>
#     from pydoll.browser.chrome import Chrome
# ModuleNotFoundError: No module named 'pydoll'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#         etype, value, tb, tb_offset=tb_offset
#     )
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, etype, value, tb, tb_offset, number_of_lines_of_context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                                                            tb_offset)
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\repos\hypotez\venv313\Lib\site-packages\IPython\core\ultratb.py", line 1179, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\repos\hypotez\venv313\Lib\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#     ...<4 lines>...
#     )
#   File "D:\repos\hypotez\venv313\Lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "D:\repos\hypotez\venv313\Lib\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#   File "D:\repos\hypotez\venv313\Lib\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "D:\repos\hypotez\venv313\Lib\site-packages\executing\executing.py", line 283, in executing
#     assert_(new_stmts <= stmts)
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "D:\repos\hypotez\venv313\Lib\site-packages\executing\executing.py", line 80, in assert_
#     raise AssertionError(str(message))
# AssertionError

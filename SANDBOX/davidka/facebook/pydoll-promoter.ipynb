# %%
import header 
from src.endpoints.advertisement.facebook.promoter import FacebookPromoter
from src.logger.logger import logger

import asyncio
from pydoll.constants import Key
from pydoll.browser.chromium.chrome import Chrome 

from src.webdriver.pydoll.tab import Tab
from src.webdriver.pydoll.options import Options
from src.webdriver.pydoll.browser import Browser
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'E:\\hypo69\\log\\1103261502'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'E:\\hypo69\\log'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'E:\\hypo69'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import header
# ----> 2 from src.endpoints.advertisement.facebook.promoter import FacebookPromoter
#       3 from src.logger.logger import logger
#       5 import asyncio
#
# File D:\repos\hypotez\src\__init__.py:17
#       1 ## \file /src/__init__.py
#       2 # -*- coding: utf-8 -*-
#       3 #! .pyenv/bin/python3
#       5 """
#       6 Root of the project.
#       7 ========================================================================================
#    (...)     14 ```
#      15 """
# ---> 17 from .check_release import check_latest_release
#      19 USE_ENV:bool = False
#      21 if USE_ENV:
#
# File D:\repos\hypotez\src\check_release.py:17
#       5 """
#       6 ```rst
#       7 .. module:: src
#    (...)     13
#      14 """
#      16 import requests
# ---> 17 from src.logger.logger import logger
#      19 def check_latest_release(repo: str, owner: str):
#      20     """Check the latest release version of a GitHub repository.
#      21
#      22     Args:
#    (...)     27         str: The latest release version if available, else None.
#      28     """
#
# File D:\repos\hypotez\src\logger\__init__.py:14
#       1 ## \file /src/logger/__init__.py
#       2 # -*- coding: utf-8 -*-
#       3
#       4 #! .pyenv/bin/python3
#       6 """
#       7 .. module:: src.logger
#       8 	:platform: Windows, Unix
#       9 	:synopsis:
#      10
#      11 """
# ---> 14 from .logger import logger
#      15 #from .beeper import Beeper
#      16 from .exceptions import ( ExecuteLocatorException,
#      17                          DefaultSettingsException,
#      18                          CredentialsError,
#      19                          PrestaShopException,
#      20                          PayloadChecksumError
#      21                         )
#
# File D:\repos\hypotez\src\logger\logger.py:248
#     243         self.log(logging.CRITICAL, message, ex, exc_info, color)
#     246 # Initialize logger with file paths
#     247 # logger = Logger(info_log_path='info.log', debug_log_path='debug.log', errors_log_path='errors.log', json_log_path='log.json')
# --> 248 logger: Logger = Logger()
#
# File D:\repos\hypotez\src\logger\logger.py:80, in SingletonMeta.__call__(cls, *args, **kwargs)
#      78     with cls._lock:
#      79         if cls not in cls._instances:
# ---> 80             instance = super().__call__(*args, **kwargs)
#      81             cls._instances[cls] = instance
#      82 return cls._instances[cls]
#
# File D:\repos\hypotez\src\logger\logger.py:133, in Logger.__init__(self, info_log_path, debug_log_path, errors_log_path, json_log_path)
#     130 self.json_log_path = base_path / (json_log_path or f"{timestamp}.json")
#     132 # Ensure directories exist
# --> 133 self.log_files_path.mkdir(parents=True, exist_ok=True)
#     135 # Ensure log files exist
#     136 self.info_log_path.touch(exist_ok=True)
#
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:726, in Path.mkdir(self, mode, parents, exist_ok)
#     724     if not parents or self.parent == self:
#     725         raise
# --> 726     self.parent.mkdir(parents=True, exist_ok=True)
#     727     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#     728 except OSError:
#     729     # Cannot rely on checking for EEXIST, since the operating system
#     730     # could give priority to other errors like EACCES or EROFS
#
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:726, in Path.mkdir(self, mode, parents, exist_ok)
#     724     if not parents or self.parent == self:
#     725         raise
# --> 726     self.parent.mkdir(parents=True, exist_ok=True)
#     727     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#     728 except OSError:
#     729     # Cannot rely on checking for EEXIST, since the operating system
#     730     # could give priority to other errors like EACCES or EROFS
#
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:726, in Path.mkdir(self, mode, parents, exist_ok)
#     724     if not parents or self.parent == self:
#     725         raise
# --> 726     self.parent.mkdir(parents=True, exist_ok=True)
#     727     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#     728 except OSError:
#     729     # Cannot rely on checking for EEXIST, since the operating system
#     730     # could give priority to other errors like EACCES or EROFS
#
# File C:\Program Files\Python-3.13.12\Lib\pathlib\_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'E:\\'

# %% [markdown]
# ```python
# ## \file src/webdriver/llm_driver/simple_browser.py
# # -*- coding: utf-8 -*-
# #! .pyenv/bin/python3
# ```
# Модуль для запуска задач с использованием LLM через LangChain и стандартных агентов.
# ==================================================================================
# (Использует инструменты, взаимодействующие с BrowserController и/или API поиска)
#
# Предоставляет функциональность для:
# - Конфигурирования моделей (Gemini, OpenAI).
# - Установки API ключей.
# - Запуска задачи с использованием LLM и доступных инструментов (веб-поиск, браузер).
# - Выполнения задачи до конечного результата (`run_task`).
# - Стриминга выполнения задачи (`stream_task`).
#
# Зависимости:
#     - langchain-openai, langchain-google-genai, langchain-core, langchainhub, langchain
#     - langchain-community (для SerpAPIWrapper)
#     - google-search-results (для SerpAPIWrapper)
#     - python-dotenv
#     - browser_use (или ваш модуль с BrowserController)
#     - src.gs, src.logger, src.utils, header
# ```rst
# .. module:: src.webdriver.llm_driver.simple_browser
# ```

# %%
import ipdb # <- трасировка и точки останова
import os
import sys
import io
import asyncio
from types import SimpleNamespace
from typing import List, Dict, Any, Optional, Callable, Type, Tuple, AsyncIterator
from pathlib import Path

# LangChain компоненты
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import AgentExecutor, create_react_agent, Tool
from langchain_core.language_models.chat_models import BaseChatModel
from langchain_core.exceptions import LangChainException
from langchain import hub
# --- Инструмент для поиска через API ---
# Убедитесь, что установлена: pip install google-search-results
from langchain_community.utilities import SerpAPIWrapper
from browser_use import Agent

# --- Внутренние модули ---
import header
from header import __root__
from src import gs
# from src.webdriver.ai_browser import tools
# from src.webdriver.ai_browser.tools import get_tools, get_tools_by_type, get_tools_by_name
from src.webdriver.llm_driver.use_llm import Config, Driver, stream_agent_execution

from src.logger import logger
from src.utils.jjson import j_loads, j_loads_ns
from src.utils.printer import pprint as print

from dotenv import load_dotenv
load_dotenv()
# Out:
# INFO     [browser_use] BrowserUse logging setup complete with level info
# INFO     [telemetry] Anonymized telemetry enabled. See https://docs.browser-use.com/development/telemetry for more information.
# INFO     [numexpr.utils] Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO     [numexpr.utils] NumExpr defaulting to 8 threads.
# WARNING  [logger_console] ⚠️ Error fetching data from git: https://api.github.com/repos/hypotez/hypo/releases/latest
#  response.status_code=404
# INFO     [logger_console] ℹ️ Асинхронные контроллеры успешно импортированы из src.webdriver.llm_driver.controllers.
# WARNING  [logger_console] ⚠️ .env файл не найден по пути: C:\Users\user\Documents\repos\hypotez\.env.
# INFO     [logger_console] ℹ️ Конфигурация успешно загружена из C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\use_llm.json
# INFO     [logger_console] ℹ️ Config Gemini: Status=active, Model=gemini-2.5-flash-preview-04-17, Key Present=True
# INFO     [logger_console] ℹ️ Config OpenAI: Status=disabled, Model=gpt-4o, Key Present=True
# INFO     [logger_console] ℹ️ Config SerpAPI: Status=inactive, Key Present=True
# INFO     [logger_console] ℹ️ Config DuckDuckGo: Status=active
# INFO     [logger_console] ℹ️ Config Tavily: Status=inactive, Key Present=False
# False

# %%
class Config:
    ENDPOINT:Path = Path(__root__/'SANDBOX'/'davidka')

# %%
class SimpleDriver(Driver):
    """"""
    def __init__(self, 
                 GEMINI_API_KEY:str = None, 
                 OPENAI_API_KEY:str = None, 
                 openai_model_name:str = None, 
                 gemini_model_name:str = None, 
                 start_browser:str = True,
                **kwargs):
        super().__init__(GEMINI_API_KEY, OPENAI_API_KEY, openai_model_name, gemini_model_name, start_browser, **kwargs) 

    async def simple_process_task_async(self, task:str = 'Hello, world!') -> Any:
        """"""

        result_dict:dict = {}

        def clean_json(raw_text: str) -> str:
            # 1. Убираем всё до первой фигурной скобки {
            try:
                json_start = raw_text.index('{')
            except Exception as ex:
                logger.error("Ошибка поиска первой фигурной скобки", ex, exc_info=True)
                return ''
            if json_start == -1:
                return raw_text  # нет скобки, вернуть как есть
            # Извлекаем текст начиная с первой фигурной скобки
            json_cleaned = raw_text[json_start:]
    
            # 2. Убираем завершающие тройные кавычки или лишние пробелы
            json_cleaned = json_cleaned.strip('`\n ')
            
            return json_cleaned

        try:
            # Инициализация агента с списком моделей и задачей
            # Убедитесь, что ваш класс Agent может принимать список LLM объектов в параметре 'llm'
            agent = Agent(
                task=task,
                llm=self.gemini, # Передача инициализированнoй модели
                # Другие параметры для Agent, если они есть
            )
            logger.info(f"Агент начинает выполнение задачи: \"{task}\"")
            # --- Перехват stdout ---
            original_stdout = sys.stdout
            sys.stdout = io.StringIO()

            try:
                answer = await agent.run()
            finally:
                sys.stdout = original_stdout  # Обязательно вернуть обратно!

            if not answer:
                logger.error('Не вернулся результат действий агента')
                ...
            answer: Any = await agent.run() # Ожидание результата работы агента
            if not answer:
                logger.error('Не вернулся результат действий агента')
                ...
            timestamp:str = gs.now

            for action_result in answer.history:
                result_list:list = getattr(action_result, 'result', None)
                result:'ActionResult' = result_list[0]
                extracted_content:str =	result.extracted_content

                cleaned_json_text = clean_json(extracted_content)
                try:
                    data = j_loads(cleaned_json_text)  # Загружаем JSON из текста
                    if not data: continue
                except Exception as ex:
                    logger.error("Ошибка разбора JSON", ex, exc_info=True)
                    ...
                    continue

                # Сохраняем данные
                timestamp = gs.now
                j_dumps(data, Config.ENDPOINT/'train_data_products'/f'product_links_{timestamp}.json')
                result_dict.update(data)

            logger.info("Агент завершил выполнение задачи.")
            ...
            return result_dict 
        except Exception as agent_err:
            logger.error(f"\n\n !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!/nПроизошла ошибка во время инициализации или выполнения задачи агентом./n!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!/n", agent_err, exc_info=True)
            ...
            return '' # Возврат None при ошибке агента

# %% [markdown]
# ```python
# ## \file /sandbox/davidka/crawler_simple_driver.py
# # -*- coding: utf-8 -*-
# #! .pyenv/bin/python3
# ```
# Модуль для сбора данных со страниц товаров через SimpleDriver
# =====================================================
# (адаптация исходного crawler.py)
# ```rst
# .. module:: sandbox.davidka.crawler_simple_driver
# ```

# %%
import asyncio
import random
from pathlib import Path

import header
from header import __root__
from src import gs
from src.webdriver.llm_driver.simple_driver import SimpleDriver
from src.utils.jjson import j_loads, j_dumps
from src.utils.file import read_text_file, save_text_file, get_filenames_from_directory
from src.utils.url import get_domain
from src.utils.string.ai_string_utils import normalize_answer
from src.utils.printer import pprint as print
from src.logger import logger

# %%
class Config:
    ENDPOINT: Path = __root__ / 'SANDBOX' / 'davidka'
    mining_data_path: Path = ENDPOINT / 'random_urls'
    train_data_supplier_categories_path: Path = ENDPOINT / 'train_data_supplier_categories'
    checked_domains: list = read_text_file(ENDPOINT / 'checked_domains.txt', as_list=True)
    crawl_files_list: list = get_filenames_from_directory(mining_data_path, 'json')
    instruction_grab_product_page_simple_driver: str = (ENDPOINT / 'instructions' / 'grab_product_page_simple_driver.md').read_text(encoding='utf-8')
    instruction_get_supplier_categories: str = (ENDPOINT / 'instructions' / 'get_supplier_categories.md').read_text(encoding='utf-8')
    instruction_find_product_in_supplier_domain: str = (ENDPOINT / 'instructions' / 'find_product_in_supplier_domain.md').read_text(encoding='utf-8')
    instruction_for_products_urls_one_product: str = (ENDPOINT / 'instructions' / 'get_product_links_one_product.md').read_text(encoding='utf-8')
    instruction_links_from_search: str = (ENDPOINT / 'instructions' / 'links_from_search.md').read_text(encoding='utf-8')
    instruction_links_from_searh_page: str = (ENDPOINT / 'instructions' / 'links_from_searh_page.md').read_text(encoding='utf-8')
    GEMINI_API_KEY = gs.credentials.gemini.teacher.api_key
    driver: SimpleDriver = SimpleDriver(gemini_model_name='gemini-1.5-flash-8b-exp-0924', GEMINI_API_KEY = GEMINI_API_KEY)
# Out:
# INFO     [logger_console] ℹ️ --- Начало СИНХРОННОЙ инициализации Driver ---
# WARNING  [logger_console] ⚠️ OpenAI LLM не инициализирован (Key=True, Status=disabled, Model=True)
# INFO     [logger_console] ℹ️ Инициализация Gemini: Model=gemini-2.5-flash-preview-04-17
# INFO     [logger_console] ℹ️ Gemini LLM инициализирован.
# INFO     [logger_console] ℹ️ --- Синхронная инициализация Driver завершена. Вызовите async_init() ---

# %%
def get_products_urls_list_from_files(crawl_files_list: list = None) -> list:
    """Читает файлы с продуктами и возвращает product_url списком"""
    products_urls_list = []
    for filename in crawl_files_list or Config.crawl_files_list:
        try:
            file_path = Config.mining_data_path / filename
            crawl_data = j_loads(file_path)['products']
            for product in crawl_data:
                products_urls_list.append(product['product_url'])
        except Exception as ex:
            logger.error(f'Ошибка при обработке файла {filename=}', ex, exc_info=True)
    random.shuffle(products_urls_list)
    return products_urls_list


def yield_product_urls_from_files(directory: Path = Config.mining_data_path, pattern: str = 'json'):
    """Генератор url продуктов из файлов"""
    filenames = get_filenames_from_directory(directory, pattern)
    for filename in filenames:
        try:
            file_path = directory / filename
            crawl_data = j_loads(file_path)['products']
            for product in crawl_data:
                yield product['product_url']
        except Exception as ex:
            logger.error(f'Ошибка при обработке файла {filename=}', ex, exc_info=True)


def get_categories_from_random_urls(crawl_files_list: list = None) -> list:
    """Возвращает все категории из файлов продуктов"""
    categories_list = []
    for filename in crawl_files_list or Config.crawl_files_list:
        try:
            file_path = Config.mining_data_path / filename
            crawl_data = j_loads(file_path)
            crawl_data = crawl_data.get('products', [])
            for product in crawl_data:
                if 'parent_category' in product:
                    categories_list.append(product['parent_category'])
                if 'category_name' in product:
                    categories_list.append(product['category_name'])
        except Exception as ex:
            logger.error(f'Ошибка при обработке файла {filename=}', ex, exc_info=True)
    categories_list = list(filter(None, set(categories_list)))
    random.shuffle(categories_list)
    return categories_list


async def get_products_urls(category: str, task:str = '', num_of_links: str = '10') -> str:
    """Получить товары по категории"""
    try:
        driver = Config.driver
        logger.info(f'Обработка {category=}')
        
        task = task or Config.instruction_links_from_searh_page.replace('{PRODUCT_CATEGORY}', category).replace('{NUM_LINKS}', num_of_links)
        #ipdb.set_trace()
        answer = await driver.simple_process_task_async(task)
        if not answer:
            return ''
        print('\n -------------------------------- EXTRACTED DATA \n------------------------------------------\n')
        print(answer)
        print('\n -------------------------------------------------------------------------------------------')
        return answer
    except Exception as ex:
        logger.error(f'Ошибка при обработке {category=}', ex, exc_info=True)
        return ''


async def fetch_categories_from_suppliers_random_urls() -> dict:
    """Сбор категорий с сайтов"""
    categories_dict = {}
    driver = Config.driver

    for filename in Config.crawl_files_list:
        try:
            file_path = Config.mining_data_path / filename
            crawl_data = j_loads(file_path)
            crawl_data = crawl_data.get('products', [])
            for product in crawl_data:
                domain = get_domain(product['product_url'])
                if domain in Config.checked_domains:
                    continue
                task = Config.instruction_get_supplier_categories.replace('{INPUT_URL}', domain)
                res = await driver.simple_process_task_async(task)
                if not res:
                    continue
                normalized_res = normalize_answer(res.get('output', ''))
                data = j_loads(normalized_res)
                print(data)
                j_dumps(data, Config.train_data_supplier_categories_path / f'{gs.now}.json')
                Config.checked_domains.append(domain)
                save_text_file(Config.checked_domains, Config.ENDPOINT / 'checked_domains.txt')
                j_dumps(Config.checked_domains, Config.ENDPOINT / 'checked_domains.json')
        except Exception as ex:
            logger.error(f'Ошибка при обработке файла {filename=}', ex, exc_info=True)
    return categories_dict

# %%
driver = Config.driver

# Пример: обработка товаров по категориям
for category in get_categories_from_random_urls():
    #ipdb.set_trace()
    if not await get_products_urls(category = category, num_of_links = '10'):
        break
# Out:
# INFO     [logger_console] ℹ️ Обработка category='Hydraulic Filter Housings'
# INFO     [agent] 🧠 Starting an agent with main_model=models/gemini-2.5-flash-preview-04-17 +vision, planner_model=None, extraction_model=None
# INFO     [logger_console] ℹ️ Агент начинает выполнение задачи: "
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Hydraulic Filter Housings`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Hydraulic Filter Housings`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
# "
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Hydraulic Filter Housings`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Hydraulic Filter Housings`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# INFO     [agent] 📍 Step 1
# INFO     [agent] 🤷 Eval: Unknown - Starting the task on an empty page.
# INFO     [agent] 🧠 Memory: Navigating to a search engine to start the task.
# INFO     [agent] 🎯 Next goal: Navigate to Google to perform the search.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://www.google.com"}}
# INFO     [controller] 🔗  Navigated to https://www.google.com
# INFO     [agent] 📍 Step 2
# INFO     [agent] 👍 Eval: Success - Successfully navigated to Google.
# INFO     [agent] 🧠 Memory: Navigated to Google and now I need to search for 'Hydraulic Filter Housings'.
# INFO     [agent] 🎯 Next goal: Input the search query and click the search button.
# INFO     [agent] 🛠️  Action 1/2: {"input_text":{"index":6,"text":"Hydraulic Filter Housings"}}
# INFO     [agent] 🛠️  Action 2/2: {"click_element_by_index":{"index":9}}
# INFO     [controller] ⌨️  Input Hydraulic Filter Housings into index 6
# INFO     [agent] Element index changed after action 1 / 2, because page changed.
# INFO     [agent] 📍 Step 3
# INFO     [agent] 👍 Eval: Success - Successfully input the search query.
# INFO     [agent] 🧠 Memory: Navigated to Google and input the search query 'Hydraulic Filter Housings'. Now I need to click the search button.
# INFO     [agent] 🎯 Next goal: Click the search button to get the search results.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":18}}
# INFO     [controller] 🖱️  Clicked button with index 18:
# INFO     [agent] 📍 Step 4
# INFO     [agent] 👍 Eval: Success - Successfully clicked the search button and landed on the search results page.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query 'Hydraulic Filter Housings', and clicked the search button. Now on the search results page. Need to extract all links and filter them.
# INFO     [agent] 🎯 Next goal: Extract all links and their URLs from the current page.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"goal":"Extract all links and their URLs from the search results on this page.","should_strip_link_urls":false}}
# INFO     [controller] 📄  Extracted from page
# : ```json
# [
#   {
#     "text": "Hydraulic Filter Assemblies",
#     "url": "https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Buy Top-Quality Hydraulic Filter Housings",
#     "url": "https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZPZrE02MqNL1czKP0UH"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.motion.com/products/Hydraulics/Hydraulic%2520Filtration/Hydraulic%2520Filter%2520Housings&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "High-Pressure Filter Housings",
#     "url": "https://www.stauffusa.com/en/category/003000/003008/003006A"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.stauffusa.com/en/category/003000/003008/003006A&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Filtration solutions for hydraulic equipment",
#     "url": "https://hifi-filter.com/en/solutions/hydraulic/"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://hifi-filter.com/en/solutions/hydraulic/&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Hydraulic Filter Housing",
#     "url": "https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.amazon.com/hydraulic-filter-housing/s?k%3Dhydraulic%2Bfilter%2Bhousing&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "What is hydraulic filter housing? | HYDAC - News",
#     "url": "https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Filter Housings",
#     "url": "https://www.filtertechnik.co.uk/filter-housings"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.filtertechnik.co.uk/filter-housings&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Hydraulic Filters for High Pressures",
#     "url": "https://www.classicfilters.com/applications/hydraulic-filters/"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.classicfilters.com/applications/hydraulic-filters/&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Hydraulic Filter Housing – Industrial Manufacturing - Pall Shop",
#     "url": "https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw&hl=iw&sl=en&tl=iw&client=search"
#   }
# ]
# ```
#
# INFO     [agent] 📍 Step 5
# INFO     [agent] 👍 Eval: Success - Successfully extracted the links from the search results page.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, clicked search, and extracted the links. Filtered the links based on the criteria. The task is complete.
# INFO     [agent] 🎯 Next goal: Provide the extracted and filtered links in the specified JSON format and finish the task.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"{\n  \"links\": [\n    \"https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/\",\n    \"https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZPZrE02MqNL1czKP0UH\",\n    \"https://www.stauffusa.com/en/category/003000/003008/003006A\",\n    \"https://hifi-filter.com/en/solutions/hydraulic/\",\n    \"https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing\",\n    \"https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html\",\n    \"https://www.filtertechnik.co.uk/filter-housings\",\n    \"https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw\"\n  ]\n}","success":true}}
# INFO     [agent] 📄 Result: {
#   "links": [
#     "https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/",
#     "https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZPZrE02MqNL1czKP0UH",
#     "https://www.stauffusa.com/en/category/003000/003008/003006A",
#     "https://hifi-filter.com/en/solutions/hydraulic/",
#     "https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing",
#     "https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html",
#     "https://www.filtertechnik.co.uk/filter-housings",
#     "https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw"
#   ]
# }
# INFO     [agent] ✅ Task completed
# INFO     [agent] ✅ Successfully
# INFO     [agent] 📝 Total input tokens used (approximate): 24759
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Hydraulic Filter Housings`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Hydraulic Filter Housings`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# INFO     [agent] 📍 Step 6
# INFO     [agent] 👍 Eval: Success - Successfully extracted and filtered the links from the search results page.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, clicked search, and extracted the links. Filtered the links based on the criteria. The task is complete.
# INFO     [agent] 🎯 Next goal: Provide the extracted and filtered links in the specified JSON format and finish the task.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"{\n  \"links\": [\n    \"https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/\",\n    \"https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZZrE02MqNL1czKP0UH\",\n    \"https://www.stauffusa.com/en/category/003000/003008/003006A\",\n    \"https://hifi-filter.com/en/solutions/hydraulic/\",\n    \"https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing\",\n    \"https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html\",\n    \"https://www.filtertechnik.co.uk/filter-housings\",\n    \"https://www.classicfilters.com/applications/hydraulic-filters/\",\n    \"https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw\"\n  ]\n}","success":true}}
# INFO     [agent] 📄 Result: {
#   "links": [
#     "https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/",
#     "https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZZrE02MqNL1czKP0UH",
#     "https://www.stauffusa.com/en/category/003000/003008/003006A",
#     "https://hifi-filter.com/en/solutions/hydraulic/",
#     "https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing",
#     "https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html",
#     "https://www.filtertechnik.co.uk/filter-housings",
#     "https://www.classicfilters.com/applications/hydraulic-filters/",
#     "https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw"
#   ]
# }
# INFO     [agent] ✅ Task completed
# INFO     [agent] ✅ Successfully
# INFO     [agent] 📝 Total input tokens used (approximate): 30802
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ JSON parsing error:
#  {
#     "text": "Hydraulic Filter Assemblies",
#     "url": "https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Buy Top-Quality Hydraulic Filter Housings",
#     "url": "https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZPZrE02MqNL1czKP0UH"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.motion.com/products/Hydraulics/Hydraulic%2520Filtration/Hydraulic%2520Filter%2520Housings&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "High-Pressure Filter Housings",
#     "url": "https://www.stauffusa.com/en/category/003000/003008/003006A"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.stauffusa.com/en/category/003000/003008/003006A&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Filtration solutions for hydraulic equipment",
#     "url": "https://hifi-filter.com/en/solutions/hydraulic/"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://hifi-filter.com/en/solutions/hydraulic/&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Hydraulic Filter Housing",
#     "url": "https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.amazon.com/hydraulic-filter-housing/s?k%3Dhydraulic%2Bfilter%2Bhousing&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "What is hydraulic filter housing? | HYDAC - News",
#     "url": "https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Filter Housings",
#     "url": "https://www.filtertechnik.co.uk/filter-housings"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.filtertechnik.co.uk/filter-housings&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Hydraulic Filters for High Pressures",
#     "url": "https://www.classicfilters.com/applications/hydraulic-filters/"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://www.classicfilters.com/applications/hydraulic-filters/&hl=iw&sl=en&tl=iw&client=search"
#   },
#   {
#     "text": "Hydraulic Filter Housing – Industrial Manufacturing - Pall Shop",
#     "url": "https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw"
#   },
#   {
#     "text": "לדף המתורגם",
#     "url": "https://translate.google.com/translate?u=https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw&hl=iw&sl=en&tl=iw&client=search"
#   }
# ] Extra data: line 4 column 4 (char 140)
# INFO     [logger_console] ℹ️ Агент завершил выполнение задачи.
#
#  -------------------------------- EXTRACTED DATA
# ------------------------------------------
#
# {
#     "links": [
#         "https://www.donaldson.com/en-us/engine/filters/products/hydraulics/assemblies/",
#         "https://www.motion.com/products/Hydraulics/Hydraulic%20Filtration/Hydraulic%20Filter%20Housings?srsltid=AfmBOookfszIP9m6kxjV-RA2NUthgkxhWV0sRZZrE02MqNL1czKP0UH",
#         "https://www.stauffusa.com/en/category/003000/003008/003006A",
#         "https://hifi-filter.com/en/solutions/hydraulic/",
#         "https://www.amazon.com/hydraulic-filter-housing/s?k=hydraulic+filter+housing",
#         "https://www.hydac.com.au/news/post/what-is-hydraulic-filter-housing.html",
#         "https://www.filtertechnik.co.uk/filter-housings",
#         "https://www.classicfilters.com/applications/hydraulic-filters/",
#         "https://shop.pall.com/us/en/industrial-manufacturing/industrial-mobile-oem/heavy-hydraulic/zidgri78mbw"
#     ]
# }
#
#  -------------------------------------------------------------------------------------------
# INFO     [logger_console] ℹ️ Обработка category='Power Transformers (Control)'
# INFO     [agent] 🧠 Starting an agent with main_model=models/gemini-2.5-flash-preview-04-17 +vision, planner_model=None, extraction_model=None
# INFO     [logger_console] ℹ️ Агент начинает выполнение задачи: "
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Power Transformers (Control)`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Power Transformers (Control)`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
# "
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Power Transformers (Control)`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Power Transformers (Control)`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# INFO     [agent] 📍 Step 1
# INFO     [agent] 🤷 Eval: Unknown - The current page is empty, so I cannot evaluate the previous goal.
# INFO     [agent] 🧠 Memory: Starting the task to find all links from the first page of search results for 'Power Transformers (Control)'. I need to go to a search engine first.
# INFO     [agent] 🎯 Next goal: Navigate to a search engine (Google) to start the search.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://www.google.com"}}
# INFO     [controller] 🔗  Navigated to https://www.google.com
# INFO     [agent] 📍 Step 2
# INFO     [agent] 👍 Eval: Success - I have successfully navigated to Google.
# INFO     [agent] 🧠 Memory: Navigated to Google. Ready to input the search query.
# INFO     [agent] 🎯 Next goal: Input the search query 'Power Transformers (Control)' into the search bar and perform the search.
# INFO     [agent] 🛠️  Action 1/2: {"input_text":{"index":6,"text":"Power Transformers (Control)"}}
# INFO     [agent] 🛠️  Action 2/2: {"click_element_by_index":{"index":9}}
# INFO     [controller] ⌨️  Input Power Transformers (Control) into index 6
# INFO     [agent] Element index changed after action 1 / 2, because page changed.
# INFO     [agent] 📍 Step 3
# INFO     [agent] 👍 Eval: Success - I have successfully input the search query.
# INFO     [agent] 🧠 Memory: Navigated to Google and input the search query. Ready to perform the search.
# INFO     [agent] 🎯 Next goal: Click the search button to get the search results for 'Power Transformers (Control)'.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":16}}
# INFO     [controller] 🖱️  Clicked button with index 16:
# INFO     [agent] 📍 Step 4
# INFO     [agent] 👍 Eval: Success - I have successfully performed the search.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, and performed the search. Now on the search results page.
# INFO     [agent] 🎯 Next goal: Scroll down to load more search results and then extract all relevant links, filtering out social media and video hosting sites.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_down":{}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [agent] 📍 Step 5
# INFO     [agent] 👍 Eval: Success - I have successfully scrolled down the page.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, and performed the search. Now on the search results page and have scrolled down once. Ready to scroll down again to load more results.
# INFO     [agent] 🎯 Next goal: Scroll down again to load more search results and then extract all relevant links, filtering out social media and video hosting sites.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_down":{}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [agent] 📍 Step 6
# INFO     [agent] 👍 Eval: Success - I have successfully scrolled down the page twice.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, and performed the search. Now on the search results page and have scrolled down twice. Ready to scroll down again to load more results.
# INFO     [agent] 🎯 Next goal: Scroll down again to load more search results and then extract all relevant links, filtering out social media and video hosting sites.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_down":{}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [agent] 📍 Step 7
# INFO     [agent] 👍 Eval: Success - I have successfully scrolled down the page multiple times to load more results.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, performed the search, and scrolled down multiple times. Now on the search results page. Ready to extract all links from the page.
# INFO     [agent] 🎯 Next goal: Extract all links from the current page and filter them according to the task requirements.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"goal":"Extract all links from the page.","should_strip_link_urls":true}}
# INFO     [controller] 📄  Extracted from page
# : ```json
# {
#   "links": [
#     "https://shinenergy.net/control-transformers-types-features-benefits-and...",
#     "https://relaytraining.com/uploads/2013/07/PT-Testing...",
#     "https://www.keysight.com/used/knowledge/guides",
#     "https://www.tiger-transformer.com/blog",
#     "https://www.reddit.com/r/hvacadvice/comments/bad_...",
#     "https://www.youtube.com/embed/?enablejsapi=1&rel=0&autoplay=0&playsinline=1&expflag=embeds_enable_muted_autoplay%3Atrue&fs=1&hl=iw",
#     "https://newtekelectricals.com/News",
#     "https://www.se.com/product-range/727...",
#     "https://www.eaton.com/machinery-controls",
#     "https://www.siemens.com/general-purpose",
#     "https://www.eaton.com/en-us/catalog",
#     "https://micronpower.com/control-faqs",
#     "https://www.rockwellautomation.com/1...",
#     "https://electricityforum.com/iep/control..."
#   ]
# }
# ```
#
# INFO     [agent] 📍 Step 8
# INFO     [agent] 👍 Eval: Success - I have successfully extracted the links from the search results page.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, performed the search, scrolled down multiple times, and extracted the links. I have filtered out social media and video hosting links.
# INFO     [agent] 🎯 Next goal: Provide the filtered links in the specified JSON format and complete the task.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"{\"links\": [\"https://shinenergy.net/control-transformers-types-features-benefits-and...\", \"https://relaytraining.com/uploads/2013/07/PT-Testing...\", \"https://www.keysight.com/used/knowledge/guides\", \"https://www.tiger-transformer.com/blog\", \"https://newtekelectricals.com/News\", \"https://www.se.com/product-range/727...\", \"https://www.eaton.com/machinery-controls\", \"https://www.siemens.com/general-purpose\", \"https://www.eaton.com/en-us/catalog\", \"https://micronpower.com/control-faqs\", \"https://www.rockwellautomation.com/1...\", \"https://electricityforum.com/iep/control...\"]}","success":true}}
# INFO     [agent] 📄 Result: {"links": ["https://shinenergy.net/control-transformers-types-features-benefits-and...", "https://relaytraining.com/uploads/2013/07/PT-Testing...", "https://www.keysight.com/used/knowledge/guides", "https://www.tiger-transformer.com/blog", "https://newtekelectricals.com/News", "https://www.se.com/product-range/727...", "https://www.eaton.com/machinery-controls", "https://www.siemens.com/general-purpose", "https://www.eaton.com/en-us/catalog", "https://micronpower.com/control-faqs", "https://www.rockwellautomation.com/1...", "https://electricityforum.com/iep/control..."]}
# INFO     [agent] ✅ Task completed
# INFO     [agent] ✅ Successfully
# INFO     [agent] 📝 Total input tokens used (approximate): 44593
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Power Transformers (Control)`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Power Transformers (Control)`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# INFO     [agent] 📍 Step 9
# INFO     [agent] 👍 Eval: Success - I have successfully extracted and filtered the links according to the task requirements.
# INFO     [agent] 🧠 Memory: Navigated to Google, input the search query, performed the search, scrolled down multiple times, extracted the links, and filtered out social media and video hosting links. The task is complete.
# INFO     [agent] 🎯 Next goal: Provide the filtered links in the specified JSON format and complete the task using the done action.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"{\"links\": [\"https://shinenergy.net/control-transformers-types-features-benefits-and...\", \"https://relaytraining.com/uploads/2013/07/PT-Testing...\", \"https://www.keysight.com/used/knowledge/guides\", \"https://www.tiger-transformer.com/blog\", \"https://newtekelectricals.com/News\", \"https://www.se.com/product-range/727...\", \"https://www.eaton.com/machinery-controls\", \"https://www.siemens.com/general-purpose\", \"https://www.eaton.com/en-us/catalog\", \"https://micronpower.com/control-faqs\", \"https://www.rockwellautomation.com/1...\", \"https://electricityforum.com/iep/control...\"]}","success":true}}
# INFO     [agent] 📄 Result: {"links": ["https://shinenergy.net/control-transformers-types-features-benefits-and...", "https://relaytraining.com/uploads/2013/07/PT-Testing...", "https://www.keysight.com/used/knowledge/guides", "https://www.tiger-transformer.com/blog", "https://newtekelectricals.com/News", "https://www.se.com/product-range/727...", "https://www.eaton.com/machinery-controls", "https://www.siemens.com/general-purpose", "https://www.eaton.com/en-us/catalog", "https://micronpower.com/control-faqs", "https://www.rockwellautomation.com/1...", "https://electricityforum.com/iep/control..."]}
# INFO     [agent] ✅ Task completed
# INFO     [agent] ✅ Successfully
# INFO     [agent] 📝 Total input tokens used (approximate): 50405
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки substring not found
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^^^^^^
# ValueError: substring not found
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# INFO     [logger_console] ℹ️ Агент завершил выполнение задачи.
#
#  -------------------------------- EXTRACTED DATA
# ------------------------------------------
#
# {
#     "links": [
#         "https://shinenergy.net/control-transformers-types-features-benefits-and...",
#         "https://relaytraining.com/uploads/2013/07/PT-Testing...",
#         "https://www.keysight.com/used/knowledge/guides",
#         "https://www.tiger-transformer.com/blog",
#         "https://newtekelectricals.com/News",
#         "https://www.se.com/product-range/727...",
#         "https://www.eaton.com/machinery-controls",
#         "https://www.siemens.com/general-purpose",
#         "https://www.eaton.com/en-us/catalog",
#         "https://micronpower.com/control-faqs",
#         "https://www.rockwellautomation.com/1...",
#         "https://electricityforum.com/iep/control..."
#     ]
# }
#
#  -------------------------------------------------------------------------------------------
# INFO     [logger_console] ℹ️ Обработка category='Building Automation Frameworks'
# INFO     [agent] 🧠 Starting an agent with main_model=models/gemini-2.5-flash-preview-04-17 +vision, planner_model=None, extraction_model=None
# INFO     [logger_console] ℹ️ Агент начинает выполнение задачи: "
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Building Automation Frameworks`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Building Automation Frameworks`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
# "
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `Building Automation Frameworks`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `Building Automation Frameworks`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# INFO     [agent] 📍 Step 1
# INFO     [agent] 🤷 Eval: Unknown - Starting the task on an empty page.
# INFO     [agent] 🧠 Memory: Navigating to a search engine to start the task.
# INFO     [agent] 🎯 Next goal: Go to google.com to perform the search.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://www.google.com"}}
# INFO     [controller] 🔗  Navigated to https://www.google.com
# INFO     [agent] 📍 Step 2
# INFO     [agent] 👍 Eval: Success - Navigated to google.com.
# INFO     [agent] 🧠 Memory: Navigated to google.com and ready to perform the search.
# INFO     [agent] 🎯 Next goal: Input the search query and click the search button.
# INFO     [agent] 🛠️  Action 1/2: {"input_text":{"index":6,"text":"Building Automation Frameworks"}}
# INFO     [agent] 🛠️  Action 2/2: {"click_element_by_index":{"index":9}}
# INFO     [controller] ⌨️  Input Building Automation Frameworks into index 6
# INFO     [agent] Element index changed after action 1 / 2, because page changed.
# INFO     [agent] 📍 Step 3
# INFO     [agent] 👍 Eval: Success - Inputted the search query.
# INFO     [agent] 🧠 Memory: Navigated to google.com, inputted the search query 'Building Automation Frameworks'. Ready to click the search button.
# INFO     [agent] 🎯 Next goal: Click the search button to get the search results.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":17}}
# INFO     [controller] 🖱️  Clicked button with index 17:
# INFO     [agent] 📍 Step 4
# INFO     [agent] 👍 Eval: Success - Clicked the search button and landed on the search results page.
# INFO     [agent] 🧠 Memory: Navigated to google.com, inputted the search query 'Building Automation Frameworks', and clicked the search button. Now on the search results page.
# INFO     [agent] 🎯 Next goal: Scroll down to load all search results on the first page and then extract the links.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_down":{}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [agent] 📍 Step 5
# INFO     [agent] 👍 Eval: Success - Scrolled down the page to load more search results.
# INFO     [agent] 🧠 Memory: Navigated to google.com, inputted the search query 'Building Automation Frameworks', clicked the search button, and scrolled down. Now on the search results page and ready to extract the links.
# INFO     [agent] 🎯 Next goal: Extract all links from the search results page.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"goal":"all links from the search results","should_strip_link_urls":false}}
# INFO     [controller] 📄  Extracted from page
# : ```json
# [
#   "https://www.reddit.com/r/softwaretesting/comments/196ejho/setting_up_a_test_automation_framework_from/",
#   "https://smartbear.com/learn/automated-testing/test-automation-frameworks/",
#   "https://www.browserstack.com/guide/test-automation-architecture",
#   "https://www.globalapptesting.com/blog/automation-testing-framework",
#   "https://www.cisco.com/c/en/us/solutions/enterprise-networks/what-is-building-automation.html",
#   "https://www.browserstack.com/guide/best-test-automation-frameworks",
#   "https://translate.google.com/translate?u=https://www.browserstack.com/guide/best-test-automation-frameworks&hl=iw&sl=en&tl=iw&client=search",
#   "https://www.browserstack.com/guide/best-test-automation-frameworks#toc1",
#   "https://www.browserstack.com/guide/best-test-automation-frameworks#toc2",
#   "https://www.browserstack.com/guide/best-test-automation-frameworks#toc3",
#   "https://www.incredibuild.com/blog/how-to-build-a-successful-test-automation-framework",
#   "https://translate.google.com/translate?u=https://www.incredibuild.com/blog/how-to-build-a-successful-test-automation-framework&hl=iw&sl=en&tl=iw&client=search",
#   "https://medium.com/@solanki.govinda/best-practices-for-designing-a-test-automation-framework-4e68ae7c3688",
#   "https://www.testim.io/blog/test-automation-frameworks/",
#   "https://translate.google.com/translate?u=https://www.testim.io/blog/test-automation-frameworks/&hl=iw&sl=en&tl=iw&client=search",
#   "https://www.testim.io/blog/test-automation-frameworks/#what-is-meant",
#   "https://www.testim.io/blog/test-automation-frameworks/#what-are-the-main-components",
#   "https://www.testim.io/blog/test-automation-frameworks/#what-are-the-types",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=0",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=40",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=106",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=173",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=203",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=222",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=310",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=357",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=405",
#   "https://www.youtube.com/watch?v=P8LbgNCdAb8&t=467",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=0",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=295",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=334",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=1709",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=2181",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=2430",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=2945",
#   "https://www.youtube.com/watch?v=D_4LZgUZ5C4&t=3200",
#   "/search?sca_esv=646451c4d605381a&udm=7&q=Building+Automation+Frameworks&sa=X&ved=2ahUKEwj8nebgj_yMAxXe2QIHHf9ENZAQ8ccDKAJ6BAhIEAQ",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=69",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=158",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=439",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=808",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=1346",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=1978",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=2275",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=3008",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=4191",
#   "https://www.youtube.com/watch?v=f_lKYOBaAGk&t=6305",
#   "https://smartbear.com/resources/ebooks/steps-for-building-a-successful-ui-automated-test/",
#   "https://translate.google.com/translate?u=https://smartbear.com/resources/ebooks/steps-for-building-a-successful-ui-automated-test/&hl=iw&sl=en&tl=iw&client=search",
#   "https://www.linkedin.com/pulse/building-test-automation-framework-8-hours-nodejs-brian-richardson-6wcrc",
#   "https://www.coursera.org/projects/building-test-automation-framework-using-selenium-and-testng",
#   "https://translate.google.com/translate?u=https://www.coursera.org/projects/building-test-automation-framework-using-selenium-and-testng&hl=iw&sl=en&tl=iw&client=search",
#   "https://www.globalapptesting.com/blog/automation-testing-framework",
#   "https://translate.google.com/translate?u=https://www.globalapptesting.com/blog/automation-testing-framework&hl=iw&sl=en&tl=iw&client=search",
#   "/search?sca_esv=646451c4d605381a&q=Automation+framework+examples&sa=X&ved=2ahUKEwj8nebgj_yMAxXe2QIHHf9ENZAQ1QJ6BAhREAE",
#   "/search?sca_esv=646451c4d605381a&q=Test+automation+framework+architecture+diagram&sa=X&ved=2ahUKEwj8nebgj_yMAxXe2QIHHf9ENZAQ1QJ6BAhPEAE",
#   "/search?sca_esv=646451c4d605381a&q=Automation+frameworks+list&sa=X&ved=2ahUKEwj8nebgj_yMAxXe2QIHHf9ENZAQ1QJ6BAhQEAE",
# ...
#   },
#   {
#     "text": "6",
#     "href": "/search?q=%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B8+%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2&sca_esv=38a9d29026412e23&ei=0kIQaM6wMPXikdUPuNyysAY&start=50&sa=N&sstk=Af40H4WnloGeC00WvHAEXK9u6PJk6dDn22UXTKCtJzLRNXMET8849SgM8z2lsKw3gGZdtKD94dj1v52bG8N3NL9pO88BdoJ-bDgkRA&ved=2ahUKEwjO4ZP9ofyMAxV1caQEHTiuDGYQ8tMDegQICxAM"
#   },
#   {
#     "text": "7",
#     "href": "/search?q=%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B8+%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2&sca_esv=38a9d29026412e23&ei=0kIQaM6wMPXikdUPuNyysAY&start=60&sa=N&sstk=Af40H4WnloGeC00WvHAEXK9u6PJk6dDn22UXTKCtJzLRNXMET8849SgM8z2lsKw3gGZdtKD94dj1v52bG8N3NL9pO88BdoJ-bDgkRA&ved=2ahUKEwjO4ZP9ofyMAxV1caQEHTiuDGYQ8tMDegQICxAO"
#   },
#   {
#     "text": "8",
#     "href": "/search?q=%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B8+%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2&sca_esv=38a9d29026412e23&ei=0kIQaM6wMPXikdUPuNyysAY&start=70&sa=N&sstk=Af40H4WnloGeC00WvHAEXK9u6PJk6dDn22UXTKCtJzLRNXMET8849SgM8z2lsKw3gGZdtKD94dj1v52bG8N3NL9pO88BdoJ-bDgkRA&ved=2ahUKEwjO4ZP9ofyMAxV1caQEHTiuDGYQ8tMDegQICxAQ"
#   },
#   {
#     "text": "9",
#     "href": "/search?q=%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B8+%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2&sca_esv=38a9d29026412e23&ei=0kIQaM6wMPXikdUPuNyysAY&start=80&sa=N&sstk=Af40H4WnloGeC00WvHAEXK9u6PJk6dDn22UXTKCtJzLRNXMET8849SgM8z2lsKw3gGZdtKD94dj1v52bG8N3NL9pO88BdoJ-bDgkRA&ved=2ahUKEwjO4ZP9ofyMAxV1caQEHTiuDGYQ8tMDegQICxAS"
#   },
#   {
#     "text": "10",
#     "href": "/search?q=%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B8+%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2&sca_esv=38a9d29026412e23&ei=0kIQaM6wMPXikdUPuNyysAY&start=90&sa=N&sstk=Af40H4WnloGeC00WvHAEXK9u6PJk6dDn22UXTKCtJzLRNXMET8849SgM8z2lsKw3gGZdtKD94dj1v52bG8N3NL9pO88BdoJ-bDgkRA&ved=2ahUKEwjO4ZP9ofyMAxV1caQEHTiuDGYQ8tMDegQICxAU"
#   },
#   {
#     "text": "הבא",
#     "href": "/search?q=%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B8+%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2&sca_esv=38a9d29026412e23&ei=0kIQaM6wMPXikdUPuNyysAY&start=10&sa=N&sstk=Af40H4WnloGeC00WvHAEXK9u6PJk6dDn22UXTKCtJzLRNXMET8849SgM8z2lsKw3gGZdtKD94dj1v52bG8N3NL9pO88BdoJ-bDgkRA&ved=2ahUKEwjO4ZP9ofyMAxV1caQEHTiuDGYQ8NMDegQICxAW"
#   },
#   {
#     "text": "רמת גן",
#     "href": "#"
#   },
#   {
#     "text": "לעדכון המיקום",
#     "href": "#"
#   },
#   {
#     "text": "מידע נוסף",
#     "href": "#"
#   },
#   {
#     "text": "עזרה",
#     "href": "https://support.google.com/websearch/?p=ws_results_help&hl=iw&fg=1"
#   },
#   {
#     "text": "שליחת משוב",
#     "href": "#"
#   },
#   {
#     "text": "פרטיות",
#     "href": "https://policies.google.com/privacy?hl=iw&fg=1"
#   },
#   {
#     "text": "תנאים",
#     "href": "https://policies.google.com/terms?hl=iw&fg=1"
#   }
# ] Extra data: line 4 column 4 (char 94)
# INFO     [logger_console] ℹ️ Агент завершил выполнение задачи.
#
#  -------------------------------- EXTRACTED DATA
# ------------------------------------------
#
# {
#     "links": [
#         "https://chenzhuisolator.ru/2024/01/31/preobrazovateli-signalov-vidy-podlyuchenie-i-primenenie-ustrojstv/",
#         "https://rusautomation.ru/catalog/s/preobrazovateli_signalov/",
#         "https://www.fujielectric.fr/ru/%D1%82%D0%B5%D1%85%D0%BD%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D0%B8/%D0%BF%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D1%8C-%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2-%D0%B8-%D0%BA%D0%BE%D0%BD%D0%B4%D0%B8%D1%86%D0%B8%D0%BE%D0%BD%D0%B5%D1%80-%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2/",
#         "https://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D1%8C",
#         "https://dewesoft.com/ru/blog/what-is-signal-conditioning",
#         "https://siderus.ru/blog/tekhnologii/printsip-raboty-preobrazovatelya-signalov/",
#         "https://tdspribor.ru/preobrazovateli-signalov/",
#         "https://evropribor.by/catalog/preobrazovateli-signalov-cs-a/",
#         "https://www.loudsound.ru/catalog/preobrazovateli/?srsltid=AfmBOop4V-XcRa7dyPOk8n9wTCfihk6w9A7fXh6ZNBigA-rcErX3D5eJ",
#         "https://www.chipdip.ru/catalog/ic-signal-converters-rus"
#     ]
# }
#
#  -------------------------------------------------------------------------------------------
# INFO     [logger_console] ℹ️ Обработка category='ACB Accessories'
# INFO     [agent] 🧠 Starting an agent with main_model=models/gemini-2.5-flash-preview-04-17 +vision, planner_model=None, extraction_model=None
# INFO     [logger_console] ℹ️ Агент начинает выполнение задачи: "
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `ACB Accessories`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `ACB Accessories`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
# "
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `ACB Accessories`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `ACB Accessories`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# INFO     [agent] 📍 Step 1
# WARNING  [langchain_google_genai.chat_models] Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ].
# ERROR    [agent] Failed to invoke model: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error 401: LLM API call failed
# INFO     [agent] 📍 Step 1
# WARNING  [langchain_google_genai.chat_models] Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ].
# ERROR    [agent] Failed to invoke model: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# ERROR    [agent] ❌ Result failed 2/3 times:
#  Error 401: LLM API call failed
# INFO     [agent] 📍 Step 1
# WARNING  [langchain_google_genai.chat_models] Retrying langchain_google_genai.chat_models._achat_with_retry.<locals>._achat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ].
# ERROR    [agent] Failed to invoke model: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 500
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# ERROR    [agent] ❌ Result failed 3/3 times:
#  Error 401: LLM API call failed
# ERROR    [agent] ❌ Stopping due to 3 consecutive failures
# INFO     [agent] 🚀 Starting task:
# ```md
# **Роль:** Ты — Автоматизированный Веб-Агент для Поиска Страниц.
#
# **Цель:**
# Найти **все ссылки** из первой страницы поиска по запросу `ACB Accessories`.
#
# **Инструкция:**
#
# 1. **Открой поисковую систему** (например, Google, Bing или аналогичную).
#
# 2.
# - **Введи запрос**: `ACB Accessories`.
#
# 3. **Из результатов поиска**:
#
#    - Собери **все ссылки** на первой странице поиска.
#    - Пропускай рекламные и спонсорские результаты.
#    - Пропускай ссылки на социальные сети и видеохостинги.
#
# 4. **Фильтрация ссылок**:
#    - Игнорируй все ссылки, в домене которых содержатся следующие ключевые слова:
#      - `youtube`
#      - `tiktok`
#      - `facebook`
#      - `instagram`
#      - `twitter`
#      - `linkedin`
#      - `pinterest`
#      - `vk`
#      - `reddit`
#      - `snapchat`
#      - и аналогичные платформы социальных сетей или видеохостингов.
#    - Проверку выполняй по части URL (поддомен и основной домен).
#    - Если URL содержит хотя бы одно из этих слов — пропускай его.
#
# 5. **Больше ничего не делай**:
#    - Не переходи по ссылкам.
#    - Не анализируй содержимое страниц.
#    - Только сохрани сами URL.
#
# ---
#
# **📦 Формат итогового ответа:**
#
# ```json
# {
#   "links": [
#     "<ссылка 1>",
#     "<ссылка 2>",
#     "<ссылка 3>",
#     "...",
#     "<последняя ссылка>"
#   ]
# }
# ```
#
# ---
#
# **⚡ Важно:**
# - Сохраняй только реальные органические результаты поиска.
# - Пропускай рекламные и спонсорские блоки.
# - Пропускай ссылки на социальные сети и видеохостинги.
# - Никаких дополнительных комментариев или пояснений — только JSON-ответ.
# ```
#
# ERROR    [agent] ❌ Stopping due to 3 consecutive failures
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки 'NoneType' object has no attribute 'index'
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'index'
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки 'NoneType' object has no attribute 'index'
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'index'
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# ERROR    [logger_console] ❌ Ошибка поиска первой фигурной скобки 'NoneType' object has no attribute 'index'
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\repos\hypotez\src\webdriver\llm_driver\simple_driver.py", line 84, in clean_json
#     json_start = raw_text.index('{')
#                  ^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'index'
# ERROR    [logger_console] ❌ JSON parsing error:
#   Expecting value: line 1 column 1 (char 0)
# INFO     [logger_console] ℹ️ Агент завершил выполнение задачи.
